# %% [markdown]
# # Exploring a Search for Supersymmetric Dark Matter
# This notebook guides you through a supersymmetry-motived dark matter search using the ATLAS Open Data. We will explore proton-proton collision events containing two lepton and missing transverse energy in the final state. By the end of this notebook, we will have reproduced a simplified analysis, including a cutflow table, histogram, and a basic statistical interpretation of the results.

# %% [markdown]
# ## What is Dark Matter?
# Ordinary matter, which can be observed and studied, makes up around 5% of the universe. About 27% of the matter in the Universe is dark matter, yet its properties remain one of the mysteries in modern physics research.
#
#
# Evidence for dark matter primarily comes from astronomical observations. One example is gravitational lensing, where gravity can bend light and distort the appearance of the galaxies in a way that cannot be explained by visible matter alone. These types of astronomical observations have led to many dark matter theories, some of which suggest that dark matter may be a new, currently undiscovered particle. These ideas are what motivate experimental searches in particle physics.
#
#
# ## The Standard Model and Beyond the Standard Model
# The Standard Model describes our current understanding of three of the four fundamental forces: electromagnetic, weak, and strong forces, excluding gravity. It classifies the known elementary particles, including the particles that make up matter (fermions) and the particles that facilitate the interactions (bosons).
# Beyond the Standard Model physics describes processes and phenomena that we cannot explain with our current understanding of the Standard Model. For example, the Standard Model does not currently provide a dark matter candidate particle. This motivates new theoretical frameworks that aim to explain these phenomena.
#
#
#
#
# ## Supersymmetry: Extending the Standard Model
# Supersymmetry (often called 'SUSY' for short) is a theoretical extension of the Standard Model that introduces a symmetry between fermions and bosons, and hypothesizes a range of new particles. These particles are the super-partners of their corresponding Standard Model particle. Within supersymmetry, neutralinos are often considered promising dark matter candidates. In particular, the lightest neutralino is a leading dark matter candidate due to being neutrally charged, weakly interacting, and stable fitting the expected properties of dark matter.
#
#
#
# In this notebook, we will focus on a supersyemmetric model preditcing chargino-neutralino production in proton-proton collisions. This process leads to a final state with two charged leptons and missing transverse energy. The Z boson decays into a pair of charged leptons($\ell$) which form the visible part of the final state, while the W boson decays hadronically, producing jets.
#
#
# We can visualize this model using a Feynman diagram, where protons collide to produce a chargino ($\tilde{X}^{\pm}_1$) and a neutralino ($\tilde{X}^{0}_2$)  with W and Z boson decays. Both the chargino and neutralino would decay into the lightest neutralino ($\tilde{X}^{0}_1$). The lightest neutralinos contribute to the missing transverse energy in our process.
#
#
#
#
# ## Searching for Invisible Particles in Collider Experiments:
# High-energy particle accelerators, such as the Large Hadron Collider (LHC), play a key role in testing, constraining, and validating theoretical models and frameworks. These accelerators collide particles at extremely high energies, allowing us to study a wide range of processes. Although some particles (like our proposed dark matter candidates) cannot be directly detected and observed, we can infer their presence from an imbalance of measured energy and momentum of the visible particles. This is why missing transverse energy is a key experimental signature in our search for dark matter and supersymmetric particles. A Toroidal LHC AppartuS (ATLAS) is one of the general purpose detectors at the LHC and we will use data from the ATLAS experiment in this analysis.

# %% [markdown]
# # Jupyter Notebooks
# This notebook provides a way to analyze the data and perform an analysis all in a single file.
#
# ### Running the Notebook:
# - To run the entire notebook, click Cell $\rightarrow$ Run All in the top menu.
# - To run an individual cell, click Cell $\rightarrow$ Run Cells in the top menu, or use the Shift+Enter keyboard shortcut.
#
# #### Possible Errors:
# If a cell produces an error or unexpected result, try to:
# 1. Read the error message carefully (sometimes a simple variable mismatch is all it takes to produce an error)
# 2. Revert the notebook to your last checkpoint (essentially a save point) and run the cell again.
#
#
# Run the next cell to install and update any required packages.

# %%
# only need to run this cell the first time you open this notebook on your computer
import sys

## update the pip package installer
#!{sys.executable} -m pip install --upgrade --user pip
## install required packages
#!{sys.executable} -m pip install --upgrade --user uproot awkward vector numpy matplotlib mt2 pandas

# %% [markdown]
# These are the python packages that will help us run our analysis.

# %%
# run this cell everytime you run the notebook
import os
import os.path

import re # for naming
import uproot # for reading .root files
import awkward as ak # to represent nested data in columnar format
import vector # for 4-momentum calculations
import time # for tracking runtimes
import math # for mathemantical functions such as sqaure root
import numpy as np # for numerical calculations such as histogramming
import pandas as pd # to data file saving
from mt2 import mt2 # for stransverse math calculation
import matplotlib.pyplot as plt # for plotting
from matplotlib.ticker import LogLocator, AutoMinorLocator, NullFormatter # plotting tick marks

import atlasopenmagic as atom # retreiving samples

# %% [markdown]
# ### Loading the Data
# First, we read in the data from where it's stored. Here, we will also define some unit definitions.

# %%
# define luminosity for our dataset
lumi = 36.0  # units of fb^-1 (inverse femtobarn)

# define values
GeV = 1.0   # gigaelectron-volts

fraction = 1.0 # reduce this if you want the code to run quicker (helpful when debugging)
                                                                                                      
opendatadir = "/storage/shared/data/ATLASOpenDataFinalRelease" # location of the files
analysis = "2lep"  # analysis skim

# %% [markdown]
# ### Choosing the Samples
# We create a dictionary to organize and hold our event samples, grouping similar samples by the type of physics process they represent.
#
# An event is a snapshot of the detector taken during a proton-proton collision containing all the reconstructed particles and detector information from that moment. Data events are collected from real collisions recorded by the detector. Monte Carlo (MC) events are simulated and model the physics processes for the backgrounds and signals.
#
#
# **Which samples do we include?**
# - **Data**: we use all available samples included in our analysis skim. The dataset we will use corresponds to the 2015-2016 data taking period.
# - **Background MC**: this selection depends on the physics process we are studying. For our analysis, which focuses on two lepton final states mediated by W and Z bosons with missing transverse energy, we include the processes that would mimic our signal.
# - **Signal MC**: this selection depends on the specific process and mass regions we want to study. Unlike the background process we will keep the signal samples separate so we can analyze specific mass pairings(splittings) or combinations.
#
#
# **Sample Names:**
# The MC event names are stored by a unique idetifier called the datasetID or DSID.
# - Check out the [metadata table](https://opendata.atlas.cern/docs/data/for_education/13TeV25_metadata):
#     - Search by the DSID we included to learn more about which processes each smaple grouping contain.
#     - Columns describe the process, generator information, and some keywords to help classify each sample.
#     - Includes all the MC samples avaible in this ATLAS Open Data release.

# %%
# Create a samples dictionary to hold our data, background MC, and signal MC samples
# TO BE UPDATED WITH JUST DSIDs
samples = {
    'data':{
        'list':[
                'data15_periodD', 'data15_periodE', 
                'data15_periodF', 'data15_periodG', 
                'data15_periodH', 'data15_periodJ',
                'data16_periodA', 'data16_periodB',
                'data16_periodC', 'data16_periodD',
                'data16_periodE', 'data16_periodF',
                'data16_periodG', 'data16_periodI',
                'data16_periodK', 'data16_periodL'
                ]       
    },
    
    
    r'W+jets':{ 
        'list':[
                '700338.Sh_2211_Wenu_maxHTpTV2_BFilter', 
                '700339.Sh_2211_Wenu_maxHTpTV2_CFilterBVeto',
                '700340.Sh_2211_Wenu_maxHTpTV2_CVetoBVeto',
                '700341.Sh_2211_Wmunu_maxHTpTV2_BFilter',
                '700342.Sh_2211_Wmunu_maxHTpTV2_CFilterBVeto',
                '700343.Sh_2211_Wmunu_maxHTpTV2_CVetoBVeto',
                ],
    },

    
    r'Z+jets':{
        'list': [
                '700320.Sh_2211_Zee_maxHTpTV2_BFilter',
                '700321.Sh_2211_Zee_maxHTpTV2_CFilterBVeto',
                '700322.Sh_2211_Zee_maxHTpTV2_CVetoBVeto',
                '700323.Sh_2211_Zmumu_maxHTpTV2_BFilter',
                '700324.Sh_2211_Zmumu_maxHTpTV2_CFilterBVeto',
                '700325.Sh_2211_Zmumu_maxHTpTV2_CVetoBVeto',
                ],
    },
    
    r'diboson':{
        'list':[
                '700492.Sh_2211_WqqZll',
                '700493.Sh_2211_ZqqZll', 
                '700494.Sh_2211_ZbbZll',
                '700600.Sh_2212_llll',
                '700601.Sh_2212_lllv',
                '700602.Sh_2212_llvv_os',
                ],
    },
    
    
    r'SingleTop':{
        'list':[
                '601624.PhPy8EG_tW_DS_dyn_dil_antitop',
                '601628.PhPy8EG_tW_DS_dyn_dil_top',
                ],
    },
        

    r'ttbar':{
        'list':[
                '410470.PhPy8EG_A14_ttbar_hdamp258p75_nonallhad',
                ],
    },
    
    
    r'Signal_C1N2_WZ_200_0':      {'list': ['563381.MGPy8EG_C1mN2_WZ_200_0_2L7_MadSpin',   '563239.MGPy8EG_C1pN2_WZ_200_0_2L7_MadSpin']},
    r'Signal_C1N2_WZ_250_0':      {'list': ['563383.MGPy8EG_C1mN2_WZ_250_0_2L7_MadSpin',   '563241.MGPy8EG_C1pN2_WZ_250_0_2L7_MadSpin']},
    r'Signal_C1N2_WZ_250_100':    {'list': ['563385.MGPy8EG_C1mN2_WZ_250_100_2L7_MadSpin', '563243.MGPy8EG_C1pN2_WZ_250_100_2L7_MadSpin']},

    r'Signal_C1N2_WZ_300_0':      {'list': ['563386.MGPy8EG_C1mN2_WZ_300_0_2L7_MadSpin',   '563244.MGPy8EG_C1pN2_WZ_300_0_2L7_MadSpin']},
    r'Signal_C1N2_WZ_300_100':    {'list': ['563388.MGPy8EG_C1mN2_WZ_300_100_2L7_MadSpin', '563246.MGPy8EG_C1pN2_WZ_300_100_2L7_MadSpin']},

    r'Signal_C1N2_WZ_350_0':      {'list': ['563390.MGPy8EG_C1mN2_WZ_350_0_2L7_MadSpin',   '563248.MGPy8EG_C1pN2_WZ_350_0_2L7_MadSpin']},
    r'Signal_C1N2_WZ_350_100':    {'list': ['563392.MGPy8EG_C1mN2_WZ_350_100_2L7_MadSpin', '563250.MGPy8EG_C1pN2_WZ_350_100_2L7_MadSpin']},
    r'Signal_C1N2_WZ_350_200':    {'list': ['563394.MGPy8EG_C1mN2_WZ_350_200_2L7_MadSpin', '563252.MGPy8EG_C1pN2_WZ_350_200_2L7_MadSpin']},

    r'Signal_C1N2_WZ_400_0':      {'list': ['563395.MGPy8EG_C1mN2_WZ_400_0_2L7_MadSpin',   '563253.MGPy8EG_C1pN2_WZ_400_0_2L7_MadSpin']},
    r'Signal_C1N2_WZ_400_100':    {'list': ['563397.MGPy8EG_C1mN2_WZ_400_100_2L7_MadSpin', '563255.MGPy8EG_C1pN2_WZ_400_100_2L7_MadSpin']},
    r'Signal_C1N2_WZ_400_200':    {'list': ['563399.MGPy8EG_C1mN2_WZ_400_200_2L7_MadSpin', '563257.MGPy8EG_C1pN2_WZ_400_200_2L7_MadSpin']},

    r'Signal_C1N2_WZ_450_0':      {'list': ['563401.MGPy8EG_C1mN2_WZ_450_0_2L7_MadSpin',   '563259.MGPy8EG_C1pN2_WZ_450_0_2L7_MadSpin']},
    r'Signal_C1N2_WZ_450_100':    {'list': ['563403.MGPy8EG_C1mN2_WZ_450_100_2L7_MadSpin', '563261.MGPy8EG_C1pN2_WZ_450_100_2L7_MadSpin']},
    r'Signal_C1N2_WZ_450_200':    {'list': ['563405.MGPy8EG_C1mN2_WZ_450_200_2L7_MadSpin', '563263.MGPy8EG_C1pN2_WZ_450_200_2L7_MadSpin']},
    r'Signal_C1N2_WZ_450_300':    {'list': ['563407.MGPy8EG_C1mN2_WZ_450_300_2L7_MadSpin', '563265.MGPy8EG_C1pN2_WZ_450_300_2L7_MadSpin']},

    r'Signal_C1N2_WZ_500_0':      {'list': ['563408.MGPy8EG_C1mN2_WZ_500_0_2L7_MadSpin',   '563266.MGPy8EG_C1pN2_WZ_500_0_2L7_MadSpin']},
    r'Signal_C1N2_WZ_500_100':    {'list': ['563410.MGPy8EG_C1mN2_WZ_500_100_2L7_MadSpin', '563268.MGPy8EG_C1pN2_WZ_500_100_2L7_MadSpin']},
    r'Signal_C1N2_WZ_500_200':    {'list': ['563412.MGPy8EG_C1mN2_WZ_500_200_2L7_MadSpin', '563270.MGPy8EG_C1pN2_WZ_500_200_2L7_MadSpin']},
    r'Signal_C1N2_WZ_500_300':    {'list': ['563414.MGPy8EG_C1mN2_WZ_500_300_2L7_MadSpin', '563272.MGPy8EG_C1pN2_WZ_500_300_2L7_MadSpin']},

    r'Signal_C1N2_WZ_550_0':      {'list': ['563416.MGPy8EG_C1mN2_WZ_550_0_2L7_MadSpin',   '563274.MGPy8EG_C1pN2_WZ_550_0_2L7_MadSpin']},
    r'Signal_C1N2_WZ_550_100':    {'list': ['563418.MGPy8EG_C1mN2_WZ_550_100_2L7_MadSpin', '563276.MGPy8EG_C1pN2_WZ_550_100_2L7_MadSpin']},
    r'Signal_C1N2_WZ_550_200':    {'list': ['563420.MGPy8EG_C1mN2_WZ_550_200_2L7_MadSpin', '563278.MGPy8EG_C1pN2_WZ_550_200_2L7_MadSpin']},
    r'Signal_C1N2_WZ_550_300':    {'list': ['563422.MGPy8EG_C1mN2_WZ_550_300_2L7_MadSpin', '563280.MGPy8EG_C1pN2_WZ_550_300_2L7_MadSpin']},
    r'Signal_C1N2_WZ_550_400':    {'list': ['563424.MGPy8EG_C1mN2_WZ_550_400_2L7_MadSpin', '563282.MGPy8EG_C1pN2_WZ_550_400_2L7_MadSpin']},

    r'Signal_C1N2_WZ_600_0':      {'list': ['563425.MGPy8EG_C1mN2_WZ_600_0_2L7_MadSpin',   '563283.MGPy8EG_C1pN2_WZ_600_0_2L7_MadSpin']},
    r'Signal_C1N2_WZ_600_100':    {'list': ['563427.MGPy8EG_C1mN2_WZ_600_100_2L7_MadSpin', '563285.MGPy8EG_C1pN2_WZ_600_100_2L7_MadSpin']},
    r'Signal_C1N2_WZ_600_200':    {'list': ['563429.MGPy8EG_C1mN2_WZ_600_200_2L7_MadSpin', '563287.MGPy8EG_C1pN2_WZ_600_200_2L7_MadSpin']},
    r'Signal_C1N2_WZ_600_300':    {'list': ['563431.MGPy8EG_C1mN2_WZ_600_300_2L7_MadSpin', '563289.MGPy8EG_C1pN2_WZ_600_300_2L7_MadSpin']},
    r'Signal_C1N2_WZ_600_400':    {'list': ['563433.MGPy8EG_C1mN2_WZ_600_400_2L7_MadSpin', '563291.MGPy8EG_C1pN2_WZ_600_400_2L7_MadSpin']},


    r'Signal_C1N2_WZ_650_0':      {'list': ['563435.MGPy8EG_C1mN2_WZ_650_0_2L7_MadSpin',   '563293.MGPy8EG_C1pN2_WZ_650_0_2L7_MadSpin']},
    r'Signal_C1N2_WZ_650_100':    {'list': ['563437.MGPy8EG_C1mN2_WZ_650_100_2L7_MadSpin', '563295.MGPy8EG_C1pN2_WZ_650_100_2L7_MadSpin']},
    r'Signal_C1N2_WZ_650_200':    {'list': ['563439.MGPy8EG_C1mN2_WZ_650_200_2L7_MadSpin', '563297.MGPy8EG_C1pN2_WZ_650_200_2L7_MadSpin']},
    r'Signal_C1N2_WZ_650_300':    {'list': ['563441.MGPy8EG_C1mN2_WZ_650_300_2L7_MadSpin', '563299.MGPy8EG_C1pN2_WZ_650_300_2L7_MadSpin']},
    r'Signal_C1N2_WZ_650_400':    {'list': ['563443.MGPy8EG_C1mN2_WZ_650_400_2L7_MadSpin', '563301.MGPy8EG_C1pN2_WZ_650_400_2L7_MadSpin']},
    r'Signal_C1N2_WZ_650_500':    {'list': ['563445.MGPy8EG_C1mN2_WZ_650_500_2L7_MadSpin', '563303.MGPy8EG_C1pN2_WZ_650_500_2L7_MadSpin']},

    r'Signal_C1N2_WZ_700_0':      {'list': ['563446.MGPy8EG_C1mN2_WZ_700_0_2L7_MadSpin',    '563304.MGPy8EG_C1pN2_WZ_700_0_2L7_MadSpin']},
    r'Signal_C1N2_WZ_700_100':    {'list': ['563448.MGPy8EG_C1mN2_WZ_700_100_2L7_MadSpin',  '563306.MGPy8EG_C1pN2_WZ_700_100_2L7_MadSpin']},
    r'Signal_C1N2_WZ_700_200':    {'list': ['563450.MGPy8EG_C1mN2_WZ_700_200_2L7_MadSpin',  '563308.MGPy8EG_C1pN2_WZ_700_200_2L7_MadSpin']},
    r'Signal_C1N2_WZ_700_300':    {'list': ['563452.MGPy8EG_C1mN2_WZ_700_300_2L7_MadSpin',  '563310.MGPy8EG_C1pN2_WZ_700_300_2L7_MadSpin']},
    r'Signal_C1N2_WZ_700_400':    {'list': ['563454.MGPy8EG_C1mN2_WZ_700_400_2L7_MadSpin',  '563312.MGPy8EG_C1pN2_WZ_700_400_2L7_MadSpin']},
    r'Signal_C1N2_WZ_700_500':    {'list': ['563456.MGPy8EG_C1mN2_WZ_700_500_2L7_MadSpin',  '563314.MGPy8EG_C1pN2_WZ_700_500_2L7_MadSpin']},


    r'Signal_C1N2_WZ_750_0':      {'list': ['563457.MGPy8EG_C1mN2_WZ_750_0_2L7_MadSpin',    '563315.MGPy8EG_C1pN2_WZ_750_0_2L7_MadSpin']},
    r'Signal_C1N2_WZ_750_100':    {'list': ['563459.MGPy8EG_C1mN2_WZ_750_100_2L7_MadSpin',  '563317.MGPy8EG_C1pN2_WZ_750_100_2L7_MadSpin']},
    r'Signal_C1N2_WZ_750_200':    {'list': ['563461.MGPy8EG_C1mN2_WZ_750_200_2L7_MadSpin',  '563319.MGPy8EG_C1pN2_WZ_750_200_2L7_MadSpin']},
    r'Signal_C1N2_WZ_750_300':    {'list': ['563463.MGPy8EG_C1mN2_WZ_750_300_2L7_MadSpin',  '563321.MGPy8EG_C1pN2_WZ_750_300_2L7_MadSpin']},
    r'Signal_C1N2_WZ_750_400':    {'list': ['563465.MGPy8EG_C1mN2_WZ_750_400_2L7_MadSpin',  '563323.MGPy8EG_C1pN2_WZ_750_400_2L7_MadSpin']},
    r'Signal_C1N2_WZ_750_500':    {'list': ['563467.MGPy8EG_C1mN2_WZ_750_500_2L7_MadSpin',  '563325.MGPy8EG_C1pN2_WZ_750_500_2L7_MadSpin']},


    r'Signal_C1N2_WZ_800_0':      {'list': ['563468.MGPy8EG_C1mN2_WZ_800_0_2L7_MadSpin',    '563326.MGPy8EG_C1pN2_WZ_800_0_2L7_MadSpin']},
    r'Signal_C1N2_WZ_800_100':    {'list': ['563470.MGPy8EG_C1mN2_WZ_800_100_2L7_MadSpin',  '563328.MGPy8EG_C1pN2_WZ_800_100_2L7_MadSpin']},
    r'Signal_C1N2_WZ_800_200':    {'list': ['563472.MGPy8EG_C1mN2_WZ_800_200_2L7_MadSpin',  '563330.MGPy8EG_C1pN2_WZ_800_200_2L7_MadSpin']},
    r'Signal_C1N2_WZ_800_300':    {'list': ['563474.MGPy8EG_C1mN2_WZ_800_300_2L7_MadSpin',  '563332.MGPy8EG_C1pN2_WZ_800_300_2L7_MadSpin']},
    r'Signal_C1N2_WZ_800_400':    {'list': ['563476.MGPy8EG_C1mN2_WZ_800_400_2L7_MadSpin',  '563334.MGPy8EG_C1pN2_WZ_800_400_2L7_MadSpin']},
    r'Signal_C1N2_WZ_800_500':    {'list': ['563478.MGPy8EG_C1mN2_WZ_800_500_2L7_MadSpin',  '563336.MGPy8EG_C1pN2_WZ_800_500_2L7_MadSpin']},


    r'Signal_C1N2_WZ_900_0':      {'list': ['563479.MGPy8EG_C1mN2_WZ_900_0_2L7_MadSpin',    '563337.MGPy8EG_C1pN2_WZ_900_0_2L7_MadSpin']},
    r'Signal_C1N2_WZ_900_100':    {'list': ['563481.MGPy8EG_C1mN2_WZ_900_100_2L7_MadSpin',  '563339.MGPy8EG_C1pN2_WZ_900_100_2L7_MadSpin']},
    r'Signal_C1N2_WZ_900_200':    {'list': ['563483.MGPy8EG_C1mN2_WZ_900_200_2L7_MadSpin',  '563341.MGPy8EG_C1pN2_WZ_900_200_2L7_MadSpin']},
    r'Signal_C1N2_WZ_900_300':    {'list': ['563485.MGPy8EG_C1mN2_WZ_900_300_2L7_MadSpin',  '563343.MGPy8EG_C1pN2_WZ_900_300_2L7_MadSpin']},
    r'Signal_C1N2_WZ_900_400':    {'list': ['563487.MGPy8EG_C1mN2_WZ_900_400_2L7_MadSpin',  '563345.MGPy8EG_C1pN2_WZ_900_400_2L7_MadSpin']},
    r'Signal_C1N2_WZ_900_500':    {'list': ['563489.MGPy8EG_C1mN2_WZ_900_500_2L7_MadSpin',  '563347.MGPy8EG_C1pN2_WZ_900_500_2L7_MadSpin']},

    r'Signal_C1N2_WZ_1000_0':      {'list': ['563490.MGPy8EG_C1mN2_WZ_1000_0_2L7_MadSpin',   '563348.MGPy8EG_C1pN2_WZ_1000_0_2L7_MadSpin']},
    r'Signal_C1N2_WZ_1000_100':    {'list': ['563492.MGPy8EG_C1mN2_WZ_1000_100_2L7_MadSpin', '563350.MGPy8EG_C1pN2_WZ_1000_100_2L7_MadSpin']},
    r'Signal_C1N2_WZ_1000_200':    {'list': ['563494.MGPy8EG_C1mN2_WZ_1000_200_2L7_MadSpin', '563352.MGPy8EG_C1pN2_WZ_1000_200_2L7_MadSpin']},
    r'Signal_C1N2_WZ_1000_300':    {'list': ['563496.MGPy8EG_C1mN2_WZ_1000_300_2L7_MadSpin', '563354.MGPy8EG_C1pN2_WZ_1000_300_2L7_MadSpin']},
    r'Signal_C1N2_WZ_1000_400':    {'list': ['563498.MGPy8EG_C1mN2_WZ_1000_400_2L7_MadSpin', '563356.MGPy8EG_C1pN2_WZ_1000_400_2L7_MadSpin']},
    r'Signal_C1N2_WZ_1000_500':    {'list': ['563500.MGPy8EG_C1mN2_WZ_1000_500_2L7_MadSpin', '563358.MGPy8EG_C1pN2_WZ_1000_500_2L7_MadSpin']},


    r'Signal_C1N2_WZ_1100_0':      {'list': ['563501.MGPy8EG_C1mN2_WZ_1100_0_2L7_MadSpin',    '563359.MGPy8EG_C1pN2_WZ_1100_0_2L7_MadSpin']},
    r'Signal_C1N2_WZ_1100_100':    {'list': ['563503.MGPy8EG_C1mN2_WZ_1100_100_2L7_MadSpin',  '563361.MGPy8EG_C1pN2_WZ_1100_100_2L7_MadSpin']},
    r'Signal_C1N2_WZ_1100_200':    {'list': ['563505.MGPy8EG_C1mN2_WZ_1100_200_2L7_MadSpin',  '563363.MGPy8EG_C1pN2_WZ_1100_200_2L7_MadSpin']},
    r'Signal_C1N2_WZ_1100_300':    {'list': ['563507.MGPy8EG_C1mN2_WZ_1100_300_2L7_MadSpin',  '563365.MGPy8EG_C1pN2_WZ_1100_300_2L7_MadSpin']},
    r'Signal_C1N2_WZ_1100_400':    {'list': ['563509.MGPy8EG_C1mN2_WZ_1100_400_2L7_MadSpin',  '563367.MGPy8EG_C1pN2_WZ_1100_400_2L7_MadSpin']},
    r'Signal_C1N2_WZ_1100_500':    {'list': ['563511.MGPy8EG_C1mN2_WZ_1100_500_2L7_MadSpin',  '563369.MGPy8EG_C1pN2_WZ_1100_500_2L7_MadSpin']},

    r'Signal_C1N2_WZ_1200_0':      {'list': ['563512.MGPy8EG_C1mN2_WZ_1200_0_2L7_MadSpin',    '563370.MGPy8EG_C1pN2_WZ_1200_0_2L7_MadSpin']},
    r'Signal_C1N2_WZ_1200_100':    {'list': ['563514.MGPy8EG_C1mN2_WZ_1200_100_2L7_MadSpin',  '563372.MGPy8EG_C1pN2_WZ_1200_100_2L7_MadSpin']},
    r'Signal_C1N2_WZ_1200_200':    {'list': ['563516.MGPy8EG_C1mN2_WZ_1200_200_2L7_MadSpin',  '563374.MGPy8EG_C1pN2_WZ_1200_200_2L7_MadSpin']},
    r'Signal_C1N2_WZ_1200_300':    {'list': ['563518.MGPy8EG_C1mN2_WZ_1200_300_2L7_MadSpin',  '563376.MGPy8EG_C1pN2_WZ_1200_300_2L7_MadSpin']},
    r'Signal_C1N2_WZ_1200_400':    {'list': ['563520.MGPy8EG_C1mN2_WZ_1200_400_2L7_MadSpin',  '563378.MGPy8EG_C1pN2_WZ_1200_400_2L7_MadSpin' ]},
    r'Signal_C1N2_WZ_1200_500':    {'list': ['563522.MGPy8EG_C1mN2_WZ_1200_500_2L7_MadSpin',  '563380.MGPy8EG_C1pN2_WZ_1200_500_2L7_MadSpin']},
}

# %% [markdown]
# ## Inspecting the Dataset
# Now that we have chosen which event samples to include in our analysis, we can inspect the files to learn more about their structure. Let's open the first data sample file and see what information we have.
#
# There are many things we can look at in each file, the next cell gives you an example of a few.
#
#
# **Try it yourself!** Open a different data or MC sample file and inspect its variables or look at other variables for this data sample.

# %%
# define the path to the location of the data samples
data_path = '/storage/shared/data/ATLASOpenDataFinalRelease/2lep/Data/'
data_analysis ='data15_periodD'
data_filepath = os.path.join(data_path,f"{data_analysis}.2lep.root")


# open the data file
with uproot.open(data_filepath) as f:
    data_tree = f["analysis"]


# inspect the data
# show a list of variables that are available in the file
print('keys = ', data_tree.keys())

#show the number of entries(events) in that file
print('Number of entries = ', data_tree.num_entries)

# show the the met values in the first 5 events
print('MET (first 5 events):', ak.to_list(data_tree.arrays(['met'], entry_stop=5)['met']))

# show some other variables for the first 5 events (group the variables by the event)
example_arrays = data_tree.arrays(['lep_n', 'lep_pt'])
for i in range(5):
    print(f"\nEvent {i}:") # Remember: in programming 0 represents the first entry
    print(f"  Number of leptons: {example_arrays['lep_n'][i]}")
    print(f"  Lepton Momentum: {example_arrays['lep_pt'][i]}")
# Out:
# keys =  ['num_events', 'sum_of_weights', 'sum_of_weights_squared', 'category', 'sig_lep', 'sig_muo', 'sig_ele', 'sig_pho', 'sig_jet', 'sig_bjet70', 'n_lep', 'n_ele', 'n_muo', 'n_jet', 'n_pho', 'n_bjet70', 'TriggerMatch_DILEPTON', 'ScaleFactor_MLTRIGGER', 'ScaleFactor_PILEUP', 'ScaleFactor_FTAG', 'mcWeight', 'xsec', 'filteff', 'kfac', 'channelNumber', 'eventNumber', 'runNumber', 'trigP', 'trigDT', 'trigT', 'trigE', 'trigDM', 'trigDE', 'trigM', 'trigMET', 'trigJ', 'trigMJ', 'trigHT', 'ScaleFactor_JVT', 'ScaleFactor_fJVT', 'jet_n', 'jet_pt', 'jet_eta', 'jet_phi', 'jet_e', 'jet_btag_quantile', 'jet_jvt', 'jet_fjvt', 'jet_passLargeRJetOR', 'largeRJet_n', 'largeRJet_pt', 'largeRJet_eta', 'largeRJet_phi', 'largeRJet_e', 'largeRJet_m', 'largeRJet_D2', 'largeRJet_passLargeRJetOR', 'jet_pt_jer1', 'jet_pt_jer2', 'ScaleFactor_ELE_Tight', 'ScaleFactor_MUON_Tight', 'ScaleFactor_ELE_Loose', 'ScaleFactor_MUON_Loose', 'ScaleFactor_LepTRIGGER', 'ScaleFactor_MuTRIGGER', 'ScaleFactor_ElTRIGGER', 'lep_n', 'lep_type', 'lep_pt', 'lep_eta', 'lep_phi', 'lep_e', 'lep_charge', 'lep_ptvarcone30', 'lep_topoetcone20', 'lep_z0', 'lep_z0sintheta', 'lep_d0', 'lep_d0sig', 'lep_passTTVA', 'lep_passLargeRJetOR', 'lep_isTightID', 'lep_isMediumID', 'lep_isLooseID', 'lep_isTightIso', 'lep_isLooseIso', 'lep_isTrigMatched', 'ScaleFactor_PHOTON_Tight', 'ScaleFactor_PHOTON_Loose', 'photon_n', 'photon_pt', 'photon_eta', 'photon_phi', 'photon_e', 'photon_ptcone20', 'photon_topoetcone40', 'photon_isLooseID', 'photon_isTightID', 'photon_isLooseIso', 'photon_isTightIso', 'ScaleFactor_TAU', 'ScaleFactor_TauTRIGGER', 'ScaleFactor_DiTauTRIGGER', 'tau_n', 'tau_pt', 'tau_eta', 'tau_phi', 'tau_e', 'tau_charge', 'tau_nTracks', 'tau_isTight', 'tau_RNNJetScore', 'tau_RNNEleScore', 'truth_jet_n', 'truth_jet_pt', 'truth_jet_eta', 'truth_jet_phi', 'truth_jet_m', 'truth_elec_n', 'truth_elec_pt', 'truth_elec_eta', 'truth_elec_phi', 'truth_muon_n', 'truth_muon_pt', 'truth_muon_eta', 'truth_muon_phi', 'truth_tau_n', 'truth_tau_pt', 'truth_tau_eta', 'truth_tau_phi', 'truth_photon_n', 'truth_photon_pt', 'truth_photon_eta', 'truth_photon_phi', 'truth_met', 'truth_met_phi', 'met', 'met_phi', 'met_sig', 'met_mpx', 'met_mpy']
# Number of entries =  150596
# MET (first 5 events): [10.363849639892578, 9.24954605102539, 10.208739280700684, 5.5387139320373535, 42.80435562133789]
#
# Event 0:
#   Number of leptons: 2
#   Lepton Momentum: [22.4, 13.4]
#
# Event 1:
#   Number of leptons: 2
#   Lepton Momentum: [37.6, 12.7]
#
# Event 2:
#   Number of leptons: 2
#   Lepton Momentum: [39.6, 40.4]
#
# Event 3:
#   Number of leptons: 2
#   Lepton Momentum: [29.5, 34.9]
#
# Event 4:
#   Number of leptons: 2
#   Lepton Momentum: [43.3, 45.6]

# %% [markdown]
# ## MC Weights
#
# Since simulations are generated in an ideal environment, applying weights and scale factors is important to accurately compare MC to data. We apply weights that account for the differences between the simulation and the real detector conditions.
#
# Cross section weights scale the number of simulated events to match the expected rate in the detector using the integrated luminosity:
# - ```filteff``` : efficiency of the simulated process
# - ```kfac``` : correction to the cross section
# - ```xsec``` : cross section of the simulated process
# - ```mcWeight```:  weight of the simulated event
#
# Scale factors correct for experimental effects like trigger efficiencies, reconstruction efficiencies, and tagging algorithms:
# - ```ScaleFactor_PILEUP``` : pileup reweighting
# - ```ScaleFactor_LepTRIGGER``` : lepton trigger efficiency
# - ```ScaleFactor_ELE_Loose``` : electron efficiency
# - ```ScaleFactor_MUON_Loose``` : muon efficiency
# - ```ScaleFacctor_FTAG``` : flavour tagging efficiency (used for b-tagging)
# - ```ScaleFactor_JVT```: jet vertex tagging efficiency

# %%
# create list of weight variables and scale factors
weight_variables = ['filteff', 'kfac', 'xsec', 'mcWeight',
                    'ScaleFactor_PILEUP', 'ScaleFactor_LepTRIGGER',
                    'ScaleFactor_ELE_Loose', 'ScaleFactor_MUON_Loose', 
                    'ScaleFactor_FTAG', 'ScaleFactor_JVT'] 

# define function to calculate weights using the weight variables
def calc_weight(weight_variables, data):
    # initial normalization weight using sum_of_weights
    total_weight = lumi * 1000 / data["sum_of_weights"]  # 1000 converts fb^-1 to pb^-1#
    
    # multiply all scale factors and event weights
    for variable in weight_variables:
        total_weight = total_weight * data[variable]  # using * for element-wise multiplication
    return total_weight

# %% [markdown]
# ## Calculating Variables
# Now that we have chosen our samples and defined our MC weights, we define and calculate variables that are important to our analysis. These include the masses, kinematic quantities, and other derived values that are not directly included in the dataset.
#
# Use the code from the data inspection step to check whether the variable is present in the dataset or if it will need to be derived.

# %%
# create a list of relevant variables that will be used in our calculations and cuts
variables = ['lep_pt', 'lep_eta', 'lep_phi', 'lep_e', 'lep_charge', 'lep_type', 'lep_n', 'trigE', 'trigM',
             'lep_isLooseID', 'lep_isMediumID', 'lep_isLooseIso', 'lep_isTrigMatched','lep_isTightID',
             'met', 'met_phi','jet_pt', 'jet_eta', 'jet_phi', 'jet_e', 'jet_btag_quantile','jet_jvt',
             'lep_passTTVA']

# %% [markdown]
# ### Invariant Mass
# The invariant mass is the mass of the particle or system of particles that is independent of the particle's motion. It is the same in any frame of reference. For two leptons, the invariant mass is given by the equation:
#
#
# $m_{\ell \ell}^2 =  m_1^2 + m_2^2 + 2(E_1 E_2 - \boldsymbol{p}_1 \cdot \boldsymbol{p}_2)$
#
#
# where
# - $m_1$, $m_2$ are the masses of the leptons
# - $E_1$, $E_2$ are the energies of the leptons
# - $\boldsymbol{p}_1$, $\boldsymbol{p}_2$ are their momentum vectors
#
#
# In the high-energy limit ($E \gg m$), we can write the invariant mass in terms of transverse momenta and angles:
#
#
# $m_{\ell \ell}^2 = 2p_{T1} p_{T2} (\cosh(\eta_1 - \eta_2) - \cos(\phi_1 - \phi_2))$
#
#
# where,
# - $p_{T1}$,$p_{T2}$ are the transverse momentum
# - $\phi_1$, $\phi_2$ are the azimuthal angle
# - $\eta_1$, $\eta_2$ are the pseudorapidity
#
#
#
#
# ### Transverse Mass
# The transverse mass ($m_T$) is the mass of the system in the plane transverse (perpendicular) to the beam. This is used when we have one at least invisible particle and one visible particle. The transverse mass is given by the equation:
#
# $m_T^2 =  2(E_T^{\ell} {E}_T^{miss} - \boldsymbol{p}^{\ell}_T \cdot {\boldsymbol{p}}^{miss}_T)$
#
# where
# - $E_T^{\ell}$ is the transverse energy of the lepton
# - ${E}_T^{miss}$ is the missing transverse energy
# - $\boldsymbol{p}^{\ell}_T$ is the lepton transverse momentum vector
# - ${\boldsymbol{p}}^{miss}_T$ is missing transverse momentum vector
#
# This can also be written in terms of the azmuthal angle differnece $\Delta \phi$ between the leptons and missing ransverse momentumn:
#
# $m_T^2 =  2 p_T^\ell E_T^{miss} (1-\cos \Delta\phi)$
#
# These equation assumes the mass of the visible particle is zero.
#
#
#
# ### Stransverse Mass
# We use the transverse mass to find the stransverse mass ($m_{T2}$) which helps us infer, estimate, and constrain the mass of a system with two invisible particles. The stransverse mass given by the following equation:
#
# $m_{T2} =\min\limits_{\boldsymbol{q}_T} \Big[\max \Big(m_T(\boldsymbol{p}_T^{\ell 1}, \boldsymbol{q}_T), \, m_T(\boldsymbol{p}_T^{\ell 2}, \boldsymbol{p}_T^{\text{miss}} - \boldsymbol{q}_T)\Big)\Big]$
#
# where,
# - $\boldsymbol{q}_T$ is a trial transverse momentumn vector of an invisible particle
#
# Check out [this reference](https://www.hep.phy.cam.ac.uk/~lester/mt2/#Introduction_and_References) for more information about the stransverse mass.
#
# **Try it yourself!** Run the analysis with the invisible particle mass equal to 0 GeV. Rerun the analysis with the invisible particle mass set to 100 GeV. Observe how the distributions of the stransverse mass, signal yields as well as the signal significances change.

# %%
# calculate invariant mass of the 2-lepton state, Note: [:, i] selects the i-th lepton in each event
def calc_mass(lep_pt, lep_eta, lep_phi, lep_e):
    lep_vec = vector.zip({"pt": lep_pt, "eta": lep_eta, "phi": lep_phi, "E": lep_e}) # create 4 vectors for each lepton
    invariant_mass = (lep_vec[:, 0] + lep_vec[:, 1]).M     # .M calculates the invariant mass
    return invariant_mass

# calculate the invariant mass and transverse momentum of the leptons (Z boson kinematics) 
def calc_Z_kinematics(lep_pt, lep_eta, lep_phi, lep_e):
    lep_vec = vector.zip({"pt": lep_pt, "eta": lep_eta, "phi": lep_phi, "E": lep_e})
    Z_vec = lep_vec[:, 0] + lep_vec[:, 1]
    return Z_vec.M, Z_vec.pt  # .pt calculates the transverse momentum

# calculate the invariant mass and transverse momentum of the jets (W boson kinematics)
def calc_W_kinematics(jet_pt, jet_eta, jet_phi, jet_e):
    jet_vec = vector.zip({"pt": jet_pt, "eta": jet_eta, "phi": jet_phi, "E": jet_e})
    W_vec = jet_vec[:, 0] + jet_vec[:, 1]
    return W_vec.M, W_vec.pt

# calculate transverse mass
def calc_mt(lep_pt, lep_phi, met, met_phi):
    transverse_mass = np.sqrt(2 * lep_pt[:, 0] * met * (1 - np.cos(lep_phi[:, 0] - met_phi)))
    return transverse_mass

# calculate stransverse mass 
def calc_mt2(lep_pt, lep_eta, lep_phi, lep_e, met, met_phi, m_invis1=0.0, m_invis2=0.0): # assume mass_invisible = 0 GeV
    lep_vec = vector.zip({"pt": lep_pt, "eta": lep_eta, "phi": lep_phi, "E": lep_e}) 
    # ensure we only use events with at least 2 leptons
    lep1 = lep_vec[:, 0]
    lep2 = lep_vec[:, 1]
    # calculate px and py for leptons
    px1 = lep1.px
    py1 = lep1.py
    m1 = lep1.mass
    px2 = lep2.px
    py2 = lep2.py
    m2 = lep2.mass
    # calculate MET px and MET py
    met_px = met * np.cos(met_phi)
    met_py = met * np.sin(met_phi)
    # mt2 calculation
    mt2_values = mt2(m1, px1, py1,
                     m2, px2, py2,
                     met_px, met_py,
                     m_invis1, m_invis2)
    return mt2_values

# %% [markdown]
# ### Angular Variables
#
# The angular separation between objects is useful to identify leptons or jets that are too close together or too close to the beam. If objects are too close, it can lead to misidentification, affecting our event selection.
#
# The angular separation between two objects is given by the following equation:
#
# $\Delta R = \sqrt{(\Delta \eta)^2 + (\Delta \phi)^2}$
#
# where
# - $\Delta \eta$ is the difference in pseudorapidity between two objects
# - $\Delta \phi$ is the azimuthal angle difference
#
# The same equation can be used for lepton pairs and jet pairs.

# %%
# calculate angular separation (delta R) between one jet pair
def calc_jet_pair_deltaR(jet_eta1, jet_phi1, jet_eta2, jet_phi2):
    delta_eta = jet_eta1 - jet_eta2
    delta_phi = np.abs(jet_phi1 - jet_phi2)
    delta_phi = np.minimum(delta_phi, 2 * np.pi - delta_phi)
    jet_pair_deltaR = np.sqrt(delta_eta**2 + delta_phi**2)
    return jet_pair_deltaR

# # calculate the delta R between leptons
def calc_deltaR_leptons(lep_eta, lep_phi):
    delta_eta = lep_eta[:, 0] - lep_eta[:, 1]
    delta_phi = np.abs(lep_phi[:, 0] - lep_phi[:, 1])
    delta_phi = np.minimum(delta_phi, 2 * np.pi - delta_phi)
    delta_R_lep = np.sqrt(delta_eta**2 + delta_phi**2)
    return delta_R_lep

# calculate W delta phi
def calc_delta_phi_pmiss_W(met_phi, jet_pt, jet_eta, jet_phi, jet_e):
    jet_vecs = vector.zip({"pt": jet_pt, "eta": jet_eta, "phi": jet_phi, "E": jet_e})
    W_vec = jet_vecs[:, 0] + jet_vecs[:, 1]
    delta_phi = np.abs(W_vec.phi - met_phi)
    delta_phi = np.minimum(delta_phi, 2 * np.pi - delta_phi)
    return delta_phi

# %% [markdown]
# ## Appling Selection Cuts
# With our variables defined, next we need to select which criteria are important for our analysis. Cuts (also called event selection criteria or selection cuts) are requirements applied to the data to isolate the events we are interested in (like our signal) from the larger background processes.
#
# In the detector, most of the events come from well understood Standard Model processes and only a small amount may come from our hypothesized signal. The cuts help filter out events that are unlikely to be associated with the signal while keeping as many signal events as possible. In other words, we reduce background while maintaining signal strength.
#
# The selection criteria we will apply in our analysis closely follow the methodogologies discussed in [this publication](https://arxiv.org/abs/1803.02762).
#
#
#
# ### Lepton Identification Cuts
# Since our skim is a two-lepton (2lep) analysis, many events have already been prefiltered. However, we still apply lepton identification cuts to ensure our selected events match our desired final states and no incorrect events passed the preselection. These cuts help avoid accidentally including events that do not meet our analysis requirements.
#
# We want to keep events that:
# - have exactly two leptons
# - have the same flavour (type)
#     - either two electrons or two muons
#     - electrons have a type number ```11```
#     - muons have a type number ```13```
# - have opposite electric charge
#     - the sum of the charge of both leptons is zero
# - pass the trigger
#     - the detector identified one of the leptons as either a muon or an electron
# - satisfy impact parameters
#     - the leptons originate from the primary interaction vertex and are not produced by secondary decays or detector noise.
#     - we will use the variable ```pass_TTVA``` (track-to-vertex-association)

# %% [markdown]
# **Programming tip!** Before we define our cuts, it’s helpful to review some common coding syntax that will appear often in our selection criteria. These are the most common operators we will use to combine and define conditions in our event selection:
#
# | Operator | Name | Description
# | :----: | :---- | :-----
# | &#124; |  OR | logical OR between conditions
# | & | AND | logical AND between conditions
# | ~ | NOT | logical NOT (negates a condition)
# | != | not equal| checks if two values are not equal
# | == | equal | checks if two values are equal
#
# **Note on programming logic:**
#
# You might wonder why, if we want events with exactly 2 leptons, we sometimes write the condition as lepton number not equal to two (```lepton_number != 2```) in the code.
#
# This is because of how we will define a cut. If an event returns ```True``` we cut it away because it does not fit our selection criteria. In this case, ```True``` means remove these events. If the event returns ```False```, we want to keep the event because it satisfies our selection criteria, so we don't want to cut it away.
#
# This logic may feel counterintuitive at first, but the important part is to stay consistent with how True and False values are interpreted in cut definitions and later in the analysis loop.

# %%
# exactly two leptons
def cut_lep_number(lep_n):
    return lep_n != 2 

# same flavour leptons (ee or mumu)
def cut_lep_type(lep_type):
    # electron type is 11,  muon type is 13
    sum_lep_type = lep_type[:, 0] + lep_type[:, 1] 
    lep_type_cut = (sum_lep_type != 22) & (sum_lep_type != 26) # sum of two electrons = 22, sum of two muons = 26
    return lep_type_cut

# opposite sign leptons (e+e- or mu+mu-)
def cut_lep_charge(lep_charge):
    sum_lep_charge = lep_charge[:, 0] + lep_charge[:, 1] != 0
    return sum_lep_charge


# Note: the next four cut definitions are the only cases where our logic is not inverted in the later analysis loop
        # events that retrun True here will be kept

# standard impact paramter lepton selection (TTVA = track-to-vertex-association)
def cut_lep_impact_TTVA(lep_passTTVA):
      return ak.all(lep_passTTVA, axis=1)
    
# ensure either the electron or muon trigger was satisified
def cut_trig(trigE,trigM):
    return trigE | trigM 

# ensure at least one of the triggers match the lepton type
def cut_trig_match(lep_trigmatch): 
    trigmatch = lep_trigmatch  
    return ak.sum(trigmatch, axis=1) >= 1 

# enure both leptosn match the identification and isolation criteria 
def ID_iso_cut(IDel,IDmu,isoel,isomu,pid): 
    thispid = pid 
    return (ak.sum(((thispid == 13) & IDmu & isomu) | ((thispid == 11) & IDel & isoel), axis=1) == 2)

# %% [markdown]
# ### Momentum and Energy Cuts
# After defining our lepton identification cuts to enusre we have events with the corret final state, we apply our kinematic cuts focusing on the momentum and energy of the particles.
#
# We apply cuts on the following kinematic variables:
#
# - transverse momentum (```pt```)
#     - ensures our leptons have enough energy
# - pseudorapidity (```eta```)
#     - restricts the leptons to regions of the detector with good acceptance
# - transverse momentum of the Z boson
#     - calculated from two leptons
# - transverse momentum of the W boson
#     - calculated from the jets in the event
# - Missing transverse energy (```met```)
#     - large missing transverse energy indicates the presesnce of invisible particles escaping detection, like neutrinos or potential SUSY or dark matter candiate particles. This is especially important in our analysis!

# %%
# leading and subleading lepton momentum requirement
def cut_lep_pt(lep_pt, pt_lep1=25, pt_lep2=25):
    return (lep_pt[:, 0] < pt_lep1) | (lep_pt[:, 1] < pt_lep2)  # [:, 0] is the leading lepton

# pseduorapidity(eta) and momentum(pt) requirement for the electons
def cut_electron_kinematics(lep_pt, lep_eta, lep_type):
    is_electron = lep_type == 11
    electron_criteria = (lep_pt < 10) | (abs(lep_eta) > 2.47)
    return ak.any(is_electron & electron_criteria, axis=1)
    
# pseduorapidity(eta) and momentum(pt) requirement for the muons
def cut_muon_kinematics(lep_pt, lep_eta, lep_type):
    is_muon = lep_type == 13
    muon_criteria = (lep_pt < 10) | (abs(lep_eta) > 2.7)
    return ak.any(is_muon & muon_criteria, axis=1)

# momeutum of the leptons associated with the Z boson 
def cut_z_pt(lep_pt, lep_eta, lep_phi, lep_e, lep_pt_value = 80):
    _, pt_Z = calc_Z_kinematics(lep_pt, lep_eta, lep_phi, lep_e) # _, ignores the other variable(s) in the function defined earlier
    return pt_Z < lep_pt_value

# momeutum of the jets associated with the W boson 
def cut_w_pt(jet_pt, jet_eta, jet_phi, jet_e, jet_pt_value = 100):
    _, pt_W = calc_W_kinematics(jet_pt, jet_eta, jet_phi, jet_e)
    return pt_W < jet_pt_value

# missing transverse energy requirement 
def cut_met(met, met_value = 150):
    return met < met_value

# %% [markdown]
# #### Test Case
# At this point we have defined about half of the cuts we plan to use in our analysis. Before applying them to the dataset in our analysis loop, we can make sure the cuts in our code are working as expected and match our logic by running an example test case. Let's test our MET cut using some example values.
#
# Remember, we want to remove and cut away events that return ```True``` because they don't fit our selection criteria.

# %%
met_test_values = ak.Array([[700], [10], [150], [70], [525]]) # example MET values for testing
test_logic = cut_met(met_test_values) # apply the MET cut from our previous definition with our test array of values
print(test_logic) # print the results
# Out:
# [[False], [True], [False], [True], [False]]

# %% [markdown]
# This is exactly what we expect, the values ```[700], [10], [150], [70], [525]``` return ```[False], [True], [False], [True], [False]```. With a 150 GeV MET cut, any event with missing transverse energy greater than or equal to 150 GeV returns ```False``` and will be kept in our analysis. Any event with missing transverse energy less than 150 GeV returns ```True``` and will be cut away because they do not fit our defined selection criteria.
#
#
# **Try it yourself!** Create similar test arrays for any of the cuts we defined and make sure the selection logic works as expected before running the analysis.

# %% [markdown]
# ### Mass Cuts
# After selecting the events with the correct objects and kinematics, we apply mass-based cuts.
#
#
# We apply cuts on the following mass variables:
# - Invariant mass (``inv_mass``)
#     - selects events consitent with Z boson decay
# - Dijet mass (``jj_mass``)
#     - selects events consistent with a hadronically decaying W boson
# - stransverse mass (``mt2``)
#     - uses the presence of the invisible particles and restricts the allowed stransverse mass region

# %%
# invariant mass reqirement
def cut_inv_mass(mass, z_min=81, z_max=101):
    return (mass < z_min) | (mass > z_max)

# mass requirement on the dijet events 
def cut_jj_mass(m_jj, jj_min = 70, jj_max = 100):
    return (m_jj < jj_min) | (m_jj > jj_max)

# s-tranverse mass requirement
def cut_mt2(mt2, mt2_value = 100):
    return mt2 < mt2_value

# %% [markdown]
# ### Angular Cuts
# Angular variables describe the separation between objects and relative orientation of the particles in the detector.
#
# We apply cuts on the following angular variables:
# - $\Delta R_{\ell \ell}$ (``R_ll``)
#     - selects events where the two jets are sufficiently separated
# - $\Delta R_{jj}$ (``R_jj``)
#     - selects events with leptons that are sufficiently separated
# - $\Delta \phi$ between W boson and missing transverse momentum (``delta_phi_pmiss_W`` )
#     - suppresses background events where missing energy may arise from a mismeasurement of a jet rather than invisible particles

# %%
# delta R reqirement between the two leptons
def cut_delta_R_ll(lep_eta, lep_phi, deltaR_value=1.8):
    delta_R = calc_deltaR_leptons(lep_eta, lep_phi)
    return delta_R > deltaR_value

# delta R reqirement between the two leading jets
def cut_delta_R_jj(jet_eta, jet_phi, deltaR_value=1.5):
    jet_eta_leading = jet_eta[:, :2]
    jet_phi_leading = jet_phi[:, :2]
    delta_R = calc_jet_pair_deltaR(jet_eta_leading[:, 0], jet_phi_leading[:, 0],
                          jet_eta_leading[:, 1], jet_phi_leading[:, 1])
    return delta_R > deltaR_value

# cut on delta phi W
def cut_delta_phi_pmiss_W(delta_phi): 
    return (delta_phi < 0.5) | (delta_phi > 3.0)

# %% [markdown]
# ### Jet Cuts
# Jets are used to reconstruct the hadronic decay of the W boson and suppress backgrounds associated with top quark production.
#
#
# We apply following jet-related cuts:
# - total number of jets
# - jet kinematics
#      - requires jets to satisfy minimum transverse momentum and pseudorapidity requirements to ensure they are well reconstructed
# - pileup jets
#     - suppress jets that originate from pileup interactions using the jet vertex tagger (JVT)
# - b-jet identification and veto
#     - b-jets are jets associated with bottom quarks
#     - events containing b-tagged jets are rejected to reduce top quark background
#     - the variable ```jet_btag_quantile```  describes the continuous working point (WP) of the flavour tagger (for example: 3 = 77% WP, 4 = 85% WP)

# %%
# total number of jets
def cut_jet_number(jet_n):
    return ak.num(jet_n) < 2 

# requirement on the leading jet and non-leading jets
def cut_jets(jet_pt, jet_eta, pt_leading=30, pt_nonleading=20, eta_max=2.5):
    eta_cut = abs(jet_eta) > eta_max
    pt_leading = jet_pt[:, :2] < pt_leading
    pt_nonleading = jet_pt[:, 2:] < pt_nonleading
    jets = ak.concatenate([eta_cut[:, :2] | pt_leading, eta_cut[:, 2:] | pt_nonleading], axis=1)
    return ak.any(jets, axis=1)

# requirement on the pileup jets using jet vertex tagger
def cut_jet_jvt(jet_pt, jet_eta, jet_jvt, pt_max=60, eta_max=2.4):
    jvt_region = (jet_pt < pt_max) & (abs(jet_eta) < eta_max)
    bad_jets = jvt_region & (~jet_jvt)
    return ak.any(bad_jets, axis=1)

# veto the b-jets with momentum requirements 
def cut_zero_bjets(jet_btag_quantile, jet_pt, jet_eta, pt_value=20, eta_max=2.5, btag_WP=3):
    bjets = ((jet_pt > pt_value) & (abs(jet_eta) < eta_max) & (jet_btag_quantile > btag_WP))
    return ak.any(bjets, axis=1)

# %% [markdown]
# ### Helper Function
# Before we run the full analysis, it's useful to create a helper function that makes adjusting our analysis selection criteria a little easier.
#
# We do this by creating a dictionary that toggles each cut on or off. This way all our calculations and cuts are already defined, but we don't have to apply every cut every time. We can easily adapt which cuts to apply for different analyses.
#
# For example: If we want to see our distribution without any requirement on missing transverse energy, we can set ```cut_met``` to ```False```. Later, if we want to apply the MET cut, we just set ```cut_met``` to ```True``` and rerun the analysis.
#
#
# **Programming tip!** Helper functions like this are a safe and adaptive way to control which parts of the code are being run. We don't need to change definitions or comment/uncomment lines and can quickly adapt the analysis.

# %%
# configure the cuts to be on or off, where "True" means this cut definition will be applied in our analysis loop
apply_cuts = {
    'cut_lep_number': True, # this cut will be applied in the analysis
    'cut_lep_type': True, 
    'cut_lep_charge': True,
    'cut_trig': True,
    'cut_trig_match': True,
    'ID_iso_cut': True,
    'cut_lep_impact_TTVA': True,
    
    'cut_lep_pt': True,
    'cut_electron_kinematics': True,
    'cut_muon_kinematics': True,
    'cut_z_pt': True,
    'cut_w_pt': True,
    'cut_met': False, # this cut will not be applied in the analysis

    'cut_inv_mass': True,
    'cut_jj_mass': True,
    'cut_mt2': True,
    
    'cut_delta_R_jj': True,
    'cut_delta_R_ll': True,
    'cut_delta_phi_pmiss_W': True,
    
    'cut_jet_number': True,
    'cut_jets': True,
    'cut_jet_jvt': True,
    'cut_zero_bjets': True,
}

# %% [markdown]
# ## Running the Analysis
# We are now ready to perform our analysis! At this stage, all our samples, variables, and cuts are defined so now it's time to loop over all the samples, apply our selection criteria, and perform our analysis.
#
#
# The goal of this analysis loop is to:
# 1. Open each sample file.
# 2. Read the event in manageable chunks of data.
# 3. Apply the cuts we defined as part of our selection criteria.
# 4. Calculate the derived variables.
# 5. Store events that pass the cuts with weights for the MC events.
# 6. Keep track of initial and remaining event counts for our samples.
#
#
# **Note on processing time:** Some samples contain millions of events, so running the full analysis on the entire dataset will take some time. To reduce runtime we can adjust the fraction at the beginning of the notebook to process only a portion of the dataset. This allows us to quickly test our analysis, but this would also mean we won't be looking at the full dataset when analyzing our results. To run the full analysis on all our defined samples make sure the fraction is set to 1.0.

# %%
# start time for data processing
start_time = time.time()

# define empty dictionary to hold awkward arrays for all data and our initial event counts(before any cuts)
all_data = {} 
initial_event_counts = {}


# loop over samples (both data and Monte Carlo)
for s in samples: 
    print('Processing '+s+' samples') # print which sample is being processed
    
    frames = [] # define empty list to hold data

    is_mc = (s != 'data') # identify whether this sample is Monte Carlo or real data
    initial_event_counts[s] = {"raw": 0, "weighted": 0.0} # initialize event counters for this sample
    
    
    # loop over each file belonging to the samples in our list of samples 
    for val in samples[s]['list']:
        # build file path depending on data or Monte Carlo
        if s == 'data':
            fileString = f"{opendatadir}/{analysis}/Data/{val}.{analysis}.root"
        else:
            fileString = f"{opendatadir}/{analysis}/MC/mc_{val}.{analysis}.root"
        print(f"\tOpening file: {fileString}")

        start = time.time()
        
        # attempt to open file and access the analysis tree
        try:
            tree = uproot.open(fileString + ":analysis")
        except Exception as e:
            # if a file cannot be opened, skip and continue
            print(f"\tFailed to open {fileString}: {e}") 
            continue

        sample_data = [] # stores data passing cuts from this file

        # loop over data in the tree
        for data in tree.iterate(variables + weight_variables + ["sum_of_weights", "lep_n"], 
                                 library="ak", 
                                 entry_stop=tree.num_entries*fraction): # process up to num_events*fraction
                                


            # number of events in this batch
            nIn = len(data)

            # count events before cuts (weighted for MC)
            initial_event_counts[s]["raw"] += nIn
            if is_mc:
                initial_event_counts[s]["weighted"] += ak.sum(calc_weight(weight_variables, data))
            else:
                initial_event_counts[s]["weighted"] += nIn
            
            
            
            # all of our event selection cuts and calculations are applied here:
                # remember each cut returns True for events we want to remove
            
            # number of leptons
            lep_n = data['lep_n']
            if apply_cuts['cut_lep_number']:
                data = data[~cut_lep_number(lep_n)]

               
            # lepton type and charge
            lep_type = data['lep_type']
            if apply_cuts['cut_lep_type']:
                data = data[~cut_lep_type(lep_type)]
            
            lep_charge = data['lep_charge']
            if apply_cuts['cut_lep_charge']:
                data = data[~cut_lep_charge(lep_charge)]
            
            
            # trigger activation and lepton quaility 
            if apply_cuts['cut_trig']: # Reminder: this cuts is kept when it retruns True, do not include ~
                data = data[cut_trig(data.trigE, data.trigM)]
            
            if apply_cuts['cut_trig_match']: # Reminder: this cut is kept when it retruns True, do not include ~
                data = data[cut_trig_match(data.lep_isTrigMatched)]
            
            if apply_cuts['ID_iso_cut']: # Reminder: this cut is kept when it retruns True, do not include ~
                data = data[ID_iso_cut(data.lep_isLooseID, data.lep_isMediumID, data.lep_isLooseIso, data.lep_isLooseIso, data.lep_type)]
            
            if apply_cuts['cut_lep_impact_TTVA']: # Reminder: this cut is kept when it retruns True, do not include ~
                data = data[cut_lep_impact_TTVA(data.lep_passTTVA)]
                
            # lepton kinematic cuts
            lep_pt = data['lep_pt']
            if apply_cuts['cut_lep_pt']:
                data = data[~cut_lep_pt(lep_pt)]
            
            if apply_cuts['cut_electron_kinematics']:
                data = data[~cut_electron_kinematics(data['lep_pt'], data['lep_eta'], data['lep_type'])]
            
            if apply_cuts['cut_muon_kinematics']:
                data = data[~cut_muon_kinematics(data['lep_pt'], data['lep_eta'], data['lep_type'])]
            
            
            # missing transverse energy cut
            if apply_cuts['cut_met']:
                data = data[~cut_met(data['met'])]
            
            
            # jet cuts
            if apply_cuts['cut_jet_number']:
                data = data[~cut_jet_number(data['jet_pt'])]
           
            if apply_cuts['cut_jets']:
                data = data[~cut_jets(data['jet_pt'], data['jet_eta'])]
           
            if apply_cuts['cut_jet_jvt']:
                data = data[~cut_jet_jvt(data['jet_pt'], data['jet_eta'], data['jet_jvt'])]
            
            if apply_cuts['cut_zero_bjets']:
                data = data[~cut_zero_bjets(data['jet_btag_quantile'], data['jet_pt'], data['jet_eta'])]
            

            # angualar separation cuts 
            if apply_cuts['cut_delta_R_jj']:
                data = data[~cut_delta_R_jj(data['jet_eta'],data['jet_phi'])]
            
            if apply_cuts['cut_delta_R_ll']:
                data = data[~cut_delta_R_ll(data['lep_eta'],data['lep_phi'])]
                

            # boson kinematic cuts
            if apply_cuts['cut_z_pt']:
                data = data[~cut_z_pt(data['lep_pt'], data['lep_eta'], data['lep_phi'], data['lep_e'])]
            
            if apply_cuts['cut_w_pt']:
                data = data[~cut_w_pt(data['jet_pt'], data['jet_eta'], data['jet_phi'], data['jet_e'])]
        
        
            # derived variable calculations 
            data['mass'] = calc_mass(data['lep_pt'], data['lep_eta'], data['lep_phi'], data['lep_e'])
            data["m_Z"], data["pt_Z"] = calc_Z_kinematics(data["lep_pt"], data["lep_eta"], data["lep_phi"], data["lep_e"])
            data["m_jj"], data["pt_W"] = calc_W_kinematics(data["jet_pt"], data["jet_eta"], data["jet_phi"], data["jet_e"])
            data['mt'] = calc_mt(data['lep_pt'], data['lep_phi'], data['met'], data['met_phi'])
            data['mt2'] = calc_mt2(data['lep_pt'], data['lep_eta'], data['lep_phi'], data['lep_e'], data['met'], data['met_phi'])
            data['deltaR_leptons'] = calc_deltaR_leptons(data['lep_eta'], data['lep_phi'])
            
           
            # these next cuts rely on our derived variables so they are placed after the calculations
            # delta phi W cut
            data['delta_phi_pmiss_W'] = calc_delta_phi_pmiss_W(data['met_phi'], data['jet_pt'], data['jet_eta'], data['jet_phi'], data['jet_e'])
            if apply_cuts['cut_delta_phi_pmiss_W']:
                data = data[~cut_delta_phi_pmiss_W(data['delta_phi_pmiss_W'])]
                

            # mass cuts
            if apply_cuts['cut_inv_mass']:
                data = data[~cut_inv_mass(data['mass'])]
            
            if apply_cuts['cut_jj_mass']:
                data = data[~cut_jj_mass(data['m_jj'])]      
           
            if apply_cuts['cut_mt2']:
                data = data[~cut_mt2(data['mt2'])]
            
            
            
            
            # store Monte Carlo weights in the data
            if 'data' not in s: # only calculates weights if the data is MC
                data['totalWeight'] = calc_weight(weight_variables, data)
            sample_data.append(data)  # append data to the whole sample data list
            
            if not 'data' in val:
                nOut = sum(data['totalWeight']) # sum of weights passing cuts in this batch 
            else:
                nOut = len(data)        
                
            elapsed = time.time() - start # time taken to process
            print("\t\t nIn: "+str(nIn)+",\t nOut: \t"+str(nOut)+"\t in "+str(round(elapsed,1))+"s") # events before and after

        # concatenate all bacthes of data from the file
        if len(sample_data) > 0:
            frames.append(ak.concatenate(sample_data))
        else:
            print(f"\t\t No events passed cuts in file: {val}")


    # finalizing the sample-level storage
    if len(frames) > 0:
        all_data[s] = ak.concatenate(frames)

        n_unweighted = len(all_data[s])

        if 'data' not in s:
            # for MC sum the total weights
            n_weighted = ak.sum(all_data[s]['totalWeight'])
            print(f"{s}: {n_unweighted} events saved after cuts "
                  f"({n_weighted:.2f} weighted events).\n")
        
        else:
            # for data, there are no weights
            print(f"{s}: {n_unweighted} data events saved after cuts.\n")
    else:
        print(f"WARNING: No events left in sample '{s}' after cuts!\n")



# calculate and print the total runtime
end_time = time.time()
total_time = end_time - start_time
print(f"\nDone processing data. Total time taken: {round(total_time, 2)} seconds.")


# print list of initial event counts before cuts
# print("\nInitial event counts before any cuts:")
# for group, counts in sorted(initial_event_counts.items()):
#     if 'data' in group:
#         print(f"{group:30s}: {counts['raw']} events (no weights)")
#     else:
#         print(f"{group:30s}: {counts['raw']} raw events, {counts['weighted']:.2f} weighted events")
# Out:
# Processing data samples
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/Data/data15_periodD.2lep.root
# 		 nIn: 150596,	 nOut: 	0	 in 0.9s
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/Data/data15_periodE.2lep.root
# 		 nIn: 916212,	 nOut: 	1	 in 4.0s
# 		 nIn: 381101,	 nOut: 	0	 in 4.8s
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/Data/data15_periodF.2lep.root
# 		 nIn: 864503,	 nOut: 	2	 in 2.2s
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/Data/data15_periodG.2lep.root
# 		 nIn: 914794,	 nOut: 	2	 in 2.6s
# 		 nIn: 914794,	 nOut: 	2	 in 4.8s
# 		 nIn: 228737,	 nOut: 	0	 in 5.4s
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/Data/data15_periodH.2lep.root
# 		 nIn: 727116,	 nOut: 	1	 in 1.3s
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/Data/data15_periodJ.2lep.root
# 		 nIn: 915856,	 nOut: 	1	 in 2.2s
# 		 nIn: 915856,	 nOut: 	0	 in 4.2s
# 		 nIn: 915856,	 nOut: 	1	 in 6.4s
# 		 nIn: 915856,	 nOut: 	0	 in 8.6s
# 		 nIn: 398261,	 nOut: 	1	 in 9.4s
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/Data/data16_periodA.2lep.root
# 		 nIn: 925481,	 nOut: 	0	 in 2.3s
# 		 nIn: 608572,	 nOut: 	1	 in 3.8s
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/Data/data16_periodB.2lep.root
# 		 nIn: 896586,	 nOut: 	1	 in 1.8s
# 		 nIn: 896586,	 nOut: 	0	 in 3.3s
# 		 nIn: 896586,	 nOut: 	0	 in 5.1s
# 		 nIn: 896586,	 nOut: 	1	 in 7.1s
# 		 nIn: 866422,	 nOut: 	1	 in 9.2s
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/Data/data16_periodC.2lep.root
# 		 nIn: 899693,	 nOut: 	0	 in 1.9s
# 		 nIn: 899693,	 nOut: 	0	 in 3.5s
# 		 nIn: 899693,	 nOut: 	2	 in 5.2s
# 		 nIn: 899693,	 nOut: 	1	 in 6.7s
# 		 nIn: 899693,	 nOut: 	1	 in 8.7s
# 		 nIn: 899693,	 nOut: 	0	 in 11.4s
# 		 nIn: 231530,	 nOut: 	0	 in 12.0s
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/Data/data16_periodD.2lep.root
# 		 nIn: 891765,	 nOut: 	1	 in 1.8s
# 		 nIn: 891765,	 nOut: 	0	 in 3.4s
# 		 nIn: 891765,	 nOut: 	1	 in 4.9s
# 		 nIn: 891765,	 nOut: 	1	 in 6.5s
# 		 nIn: 891765,	 nOut: 	0	 in 8.1s
# 		 nIn: 891765,	 nOut: 	4	 in 10.0s
# 		 nIn: 891765,	 nOut: 	0	 in 12.6s
# 		 nIn: 891765,	 nOut: 	0	 in 15.5s
# 		 nIn: 891765,	 nOut: 	1	 in 18.1s
# 		 nIn: 891765,	 nOut: 	0	 in 20.8s
# 		 nIn: 891765,	 nOut: 	0	 in 23.2s
# 		 nIn: 891765,	 nOut: 	1	 in 25.4s
# 		 nIn: 400839,	 nOut: 	1	 in 26.3s
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/Data/data16_periodE.2lep.root
# 		 nIn: 896512,	 nOut: 	0	 in 1.7s
# 		 nIn: 896512,	 nOut: 	0	 in 3.4s
# 		 nIn: 896512,	 nOut: 	1	 in 4.9s
# 		 nIn: 870414,	 nOut: 	0	 in 6.3s
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/Data/data16_periodF.2lep.root
# 		 nIn: 880826,	 nOut: 	2	 in 1.7s
# 		 nIn: 880826,	 nOut: 	2	 in 3.2s
# 		 nIn: 880826,	 nOut: 	1	 in 4.8s
# 		 nIn: 880826,	 nOut: 	0	 in 6.3s
# 		 nIn: 880826,	 nOut: 	4	 in 7.9s
# 		 nIn: 880826,	 nOut: 	1	 in 9.5s
# 		 nIn: 880826,	 nOut: 	1	 in 11.0s
# 		 nIn: 880826,	 nOut: 	0	 in 12.6s
# 		 nIn: 685519,	 nOut: 	1	 in 13.9s
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/Data/data16_periodG.2lep.root
# 		 nIn: 878246,	 nOut: 	0	 in 1.7s
# 		 nIn: 878246,	 nOut: 	0	 in 3.1s
# 		 nIn: 878246,	 nOut: 	1	 in 4.6s
# 		 nIn: 878246,	 nOut: 	0	 in 6.2s
# 		 nIn: 878246,	 nOut: 	0	 in 7.7s
# 		 nIn: 878246,	 nOut: 	0	 in 9.2s
# 		 nIn: 878246,	 nOut: 	1	 in 10.7s
# 		 nIn: 878246,	 nOut: 	1	 in 12.3s
# 		 nIn: 878246,	 nOut: 	0	 in 13.9s
# 		 nIn: 815412,	 nOut: 	1	 in 15.6s
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/Data/data16_periodI.2lep.root
# 		 nIn: 880454,	 nOut: 	2	 in 1.8s
# 		 nIn: 880454,	 nOut: 	1	 in 3.2s
# 		 nIn: 880454,	 nOut: 	4	 in 4.8s
# 		 nIn: 880454,	 nOut: 	2	 in 6.3s
# 		 nIn: 880454,	 nOut: 	0	 in 7.8s
# 		 nIn: 880454,	 nOut: 	1	 in 9.4s
# 		 nIn: 880454,	 nOut: 	0	 in 11.0s
# 		 nIn: 880454,	 nOut: 	1	 in 12.6s
# 		 nIn: 880454,	 nOut: 	1	 in 14.1s
# 		 nIn: 880454,	 nOut: 	0	 in 15.9s
# 		 nIn: 880454,	 nOut: 	1	 in 17.7s
# 		 nIn: 880454,	 nOut: 	0	 in 20.0s
# 		 nIn: 880454,	 nOut: 	0	 in 21.9s
# 		 nIn: 880454,	 nOut: 	2	 in 24.0s
# 		 nIn: 817691,	 nOut: 	0	 in 25.7s
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/Data/data16_periodK.2lep.root
# 		 nIn: 881732,	 nOut: 	3	 in 1.7s
# 		 nIn: 881732,	 nOut: 	0	 in 3.2s
# 		 nIn: 881732,	 nOut: 	0	 in 4.7s
# 		 nIn: 881732,	 nOut: 	1	 in 6.3s
# 		 nIn: 881732,	 nOut: 	0	 in 7.8s
# 		 nIn: 603261,	 nOut: 	0	 in 8.9s
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/Data/data16_periodL.2lep.root
# 		 nIn: 873636,	 nOut: 	0	 in 1.9s
# 		 nIn: 873636,	 nOut: 	1	 in 3.5s
# 		 nIn: 873636,	 nOut: 	1	 in 5.0s
# 		 nIn: 873636,	 nOut: 	2	 in 6.6s
# 		 nIn: 873636,	 nOut: 	0	 in 8.1s
# 		 nIn: 873636,	 nOut: 	3	 in 9.8s
# 		 nIn: 873636,	 nOut: 	3	 in 11.5s
# 		 nIn: 873636,	 nOut: 	1	 in 13.2s
# 		 nIn: 873636,	 nOut: 	0	 in 14.8s
# 		 nIn: 873636,	 nOut: 	1	 in 16.4s
# 		 nIn: 873636,	 nOut: 	0	 in 18.2s
# 		 nIn: 873636,	 nOut: 	2	 in 20.4s
# 		 nIn: 873636,	 nOut: 	2	 in 22.5s
# 		 nIn: 873636,	 nOut: 	0	 in 24.7s
# 		 nIn: 873636,	 nOut: 	1	 in 26.9s
# 		 nIn: 785821,	 nOut: 	0	 in 29.1s
# data: 82 data events saved after cuts.
#
# Processing W+jets samples
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_700338.Sh_2211_Wenu_maxHTpTV2_BFilter.2lep.root
# 		 nIn: 170152,	 nOut: 	0	 in 1.7s
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_700339.Sh_2211_Wenu_maxHTpTV2_CFilterBVeto.2lep.root
# 		 nIn: 543379,	 nOut: 	0	 in 4.1s
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_700340.Sh_2211_Wenu_maxHTpTV2_CVetoBVeto.2lep.root
# 		 nIn: 362068,	 nOut: 	0	 in 3.9s
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_700341.Sh_2211_Wmunu_maxHTpTV2_BFilter.2lep.root
# 		 nIn: 189788,	 nOut: 	0	 in 1.8s
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_700342.Sh_2211_Wmunu_maxHTpTV2_CFilterBVeto.2lep.root
# 		 nIn: 517857,	 nOut: 	0	 in 3.7s
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_700343.Sh_2211_Wmunu_maxHTpTV2_CVetoBVeto.2lep.root
# 		 nIn: 331384,	 nOut: 	0	 in 3.4s
# W+jets: 0 events saved after cuts (0.00 weighted events).
#
# Processing Z+jets samples
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_700320.Sh_2211_Zee_maxHTpTV2_BFilter.2lep.root
# 		 nIn: 608884,	 nOut: 	0.5933257392090603	 in 1.4s
# 		 nIn: 608884,	 nOut: 	0.12955975557389005	 in 2.8s
# 		 nIn: 608884,	 nOut: 	0.49903421694858385	 in 4.1s
# 		 nIn: 421312,	 nOut: 	0.7325928533798279	 in 5.1s
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_700321.Sh_2211_Zee_maxHTpTV2_CFilterBVeto.2lep.root
# 		 nIn: 627353,	 nOut: 	0.16472534267072103	 in 1.6s
# 		 nIn: 627353,	 nOut: 	0.41532482791402625	 in 3.0s
# 		 nIn: 627353,	 nOut: 	0.2780155792720817	 in 4.4s
# 		 nIn: 627353,	 nOut: 	0.3719764528131393	 in 5.9s
# 		 nIn: 627353,	 nOut: 	0.5376055737543759	 in 7.3s
# 		 nIn: 627353,	 nOut: 	0.24625879609766288	 in 8.8s
# 		 nIn: 627353,	 nOut: 	0.8121449098243633	 in 10.2s
# 		 nIn: 627353,	 nOut: 	0.07190660212906935	 in 11.7s
# 		 nIn: 627353,	 nOut: 	0.5726606969615444	 in 13.2s
# 		 nIn: 627353,	 nOut: 	-0.0073765909428709815	 in 14.6s
# 		 nIn: 627353,	 nOut: 	0.30861143920633144	 in 16.1s
# 		 nIn: 627353,	 nOut: 	0.40232289570483587	 in 17.5s
# 		 nIn: 627353,	 nOut: 	0.6218122705987215	 in 19.0s
# 		 nIn: 627353,	 nOut: 	0.4473494052563292	 in 20.5s
# 		 nIn: 627353,	 nOut: 	0.4662286565770814	 in 22.0s
# 		 nIn: 627353,	 nOut: 	0.4401820127358741	 in 23.5s
# 		 nIn: 21204,	 nOut: 	0	 in 23.7s
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_700322.Sh_2211_Zee_maxHTpTV2_CVetoBVeto.2lep.root
# 		 nIn: 667904,	 nOut: 	-0.005009883679947355	 in 1.7s
# 		 nIn: 667904,	 nOut: 	0.41654893837914136	 in 3.3s
# 		 nIn: 667904,	 nOut: 	0.3518217420719125	 in 4.8s
# 		 nIn: 667904,	 nOut: 	0.20208084831585899	 in 6.4s
# 		 nIn: 667904,	 nOut: 	0.16240153344963792	 in 7.9s
# 		 nIn: 667904,	 nOut: 	0.14788180202383727	 in 9.5s
# 		 nIn: 667904,	 nOut: 	0.1646011781254739	 in 10.9s
# 		 nIn: 667904,	 nOut: 	0.12612104900536922	 in 12.4s
# 		 nIn: 667904,	 nOut: 	0.17289570851772332	 in 14.0s
# 		 nIn: 667904,	 nOut: 	0.3227090580756842	 in 15.5s
# 		 nIn: 667904,	 nOut: 	0.29810796099882086	 in 17.0s
# 		 nIn: 667904,	 nOut: 	0.06754243058097922	 in 18.6s
# 		 nIn: 667904,	 nOut: 	-0.09821538666559569	 in 20.1s
# 		 nIn: 667904,	 nOut: 	-0.0006257694843478032	 in 21.6s
# 		 nIn: 667904,	 nOut: 	0.2714016513474004	 in 23.1s
# 		 nIn: 667904,	 nOut: 	0.20735137041929702	 in 24.6s
# 		 nIn: 667904,	 nOut: 	0.18515368503066493	 in 26.1s
# 		 nIn: 667904,	 nOut: 	0.1648161207320237	 in 27.6s
# 		 nIn: 667904,	 nOut: 	0.1627101943008536	 in 29.1s
# 		 nIn: 667904,	 nOut: 	0.083910981791498	 in 30.7s
# 		 nIn: 667904,	 nOut: 	0.15861146523220152	 in 32.2s
# 		 nIn: 667904,	 nOut: 	0.4566357170855482	 in 33.7s
# 		 nIn: 667904,	 nOut: 	0.14572015354950235	 in 35.2s
# 		 nIn: 667904,	 nOut: 	0.26694633119782357	 in 36.7s
# 		 nIn: 667904,	 nOut: 	0.058596528528861824	 in 38.2s
# 		 nIn: 667904,	 nOut: 	0.339464705575529	 in 39.7s
# 		 nIn: 667904,	 nOut: 	0.3213661390365381	 in 41.1s
# 		 nIn: 667904,	 nOut: 	0.20232892739432715	 in 42.6s
# 		 nIn: 667904,	 nOut: 	0.15064617008298709	 in 44.2s
# 		 nIn: 667904,	 nOut: 	0.30544397661012995	 in 45.6s
# 		 nIn: 667904,	 nOut: 	0.19687580209442362	 in 47.1s
# 		 nIn: 667904,	 nOut: 	-0.011635922199240478	 in 48.7s
# 		 nIn: 667904,	 nOut: 	0.2147353117703011	 in 50.2s
# 		 nIn: 667904,	 nOut: 	0.16489841822736168	 in 51.7s
# 		 nIn: 667904,	 nOut: 	0.1599735513237038	 in 53.1s
# 		 nIn: 667904,	 nOut: 	0.13371632248874232	 in 54.7s
# 		 nIn: 667904,	 nOut: 	0.8400712629212956	 in 56.2s
# 		 nIn: 667904,	 nOut: 	0.09119164546937665	 in 57.8s
# 		 nIn: 667904,	 nOut: 	0.26690804493911496	 in 59.4s
# 		 nIn: 667904,	 nOut: 	0.5252267353988314	 in 60.9s
# 		 nIn: 667904,	 nOut: 	0.27472986847368835	 in 62.5s
# 		 nIn: 667904,	 nOut: 	0.061350556381209696	 in 64.0s
# 		 nIn: 667904,	 nOut: 	0.4183997228483779	 in 65.6s
# 		 nIn: 667904,	 nOut: 	0.23654430474125562	 in 67.1s
# 		 nIn: 667904,	 nOut: 	0.2960896213135659	 in 68.6s
# 		 nIn: 667904,	 nOut: 	0.5422838167832672	 in 70.2s
# 		 nIn: 667904,	 nOut: 	0.173832669489842	 in 71.7s
# 		 nIn: 667904,	 nOut: 	0.15701663883571135	 in 73.2s
# 		 nIn: 667904,	 nOut: 	0.06892515048298159	 in 74.8s
# 		 nIn: 667904,	 nOut: 	-0.06675671786885987	 in 76.4s
# 		 nIn: 667904,	 nOut: 	0.3154323518008533	 in 77.9s
# 		 nIn: 667904,	 nOut: 	0.20655562352255072	 in 79.4s
# 		 nIn: 667904,	 nOut: 	0.2246492990107673	 in 81.0s
# 		 nIn: 667904,	 nOut: 	0.427099356482226	 in 82.6s
# 		 nIn: 579271,	 nOut: 	0.2888582328027253	 in 84.0s
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_700323.Sh_2211_Zmumu_maxHTpTV2_BFilter.2lep.root
# 		 nIn: 609711,	 nOut: 	0.7241178404977114	 in 1.4s
# 		 nIn: 609711,	 nOut: 	0.17205247515278685	 in 2.7s
# 		 nIn: 609711,	 nOut: 	0.2324006596605425	 in 4.1s
# 		 nIn: 565435,	 nOut: 	1.522700959278888	 in 5.3s
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_700324.Sh_2211_Zmumu_maxHTpTV2_CFilterBVeto.2lep.root
# 		 nIn: 627025,	 nOut: 	0.46225172301569256	 in 1.5s
# 		 nIn: 627025,	 nOut: 	0.3723494922000344	 in 2.9s
# 		 nIn: 627025,	 nOut: 	0.554444453231152	 in 4.3s
# 		 nIn: 627025,	 nOut: 	0.5507094659117021	 in 5.7s
# 		 nIn: 627025,	 nOut: 	0.19583503180241313	 in 7.1s
# 		 nIn: 627025,	 nOut: 	0.5076179369092854	 in 8.6s
# 		 nIn: 627025,	 nOut: 	0.7441128648382127	 in 10.0s
# 		 nIn: 627025,	 nOut: 	0.34596823569250384	 in 11.4s
# 		 nIn: 627025,	 nOut: 	0.21559679246950023	 in 12.8s
# 		 nIn: 627025,	 nOut: 	0.1914418438433391	 in 14.2s
# 		 nIn: 627025,	 nOut: 	0.1873864498193522	 in 15.5s
# 		 nIn: 627025,	 nOut: 	0.3470545734493977	 in 17.0s
# 		 nIn: 627025,	 nOut: 	0.25540683583249046	 in 18.4s
# 		 nIn: 627025,	 nOut: 	0.6176715363134458	 in 19.8s
# 		 nIn: 627025,	 nOut: 	0.05782963312687853	 in 21.2s
# 		 nIn: 627025,	 nOut: 	0.30935942976143477	 in 22.6s
# 		 nIn: 627025,	 nOut: 	0.3670641587214136	 in 24.0s
# 		 nIn: 627025,	 nOut: 	-0.7276915904170488	 in 25.5s
# 		 nIn: 95236,	 nOut: 	0.2088831627893929	 in 25.8s
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_700325.Sh_2211_Zmumu_maxHTpTV2_CVetoBVeto.2lep.root
# 		 nIn: 669999,	 nOut: 	0.2070102916116239	 in 1.8s
# 		 nIn: 669999,	 nOut: 	0.35971522189539284	 in 3.2s
# 		 nIn: 669999,	 nOut: 	0.42999905953184014	 in 4.6s
# 		 nIn: 669999,	 nOut: 	0.163400750679386	 in 6.1s
# 		 nIn: 669999,	 nOut: 	0.33764067979212325	 in 7.5s
# 		 nIn: 669999,	 nOut: 	0.20003314248044674	 in 9.0s
# 		 nIn: 669999,	 nOut: 	0.043617005404025244	 in 10.4s
# 		 nIn: 669999,	 nOut: 	0.29527750983537093	 in 11.8s
# 		 nIn: 669999,	 nOut: 	0.14822906290210902	 in 13.2s
# 		 nIn: 669999,	 nOut: 	0.21657650097564768	 in 14.6s
# 		 nIn: 669999,	 nOut: 	0.12881875450013003	 in 16.2s
# 		 nIn: 669999,	 nOut: 	0.26109773307150924	 in 17.6s
# 		 nIn: 669999,	 nOut: 	0.2810798043735346	 in 19.1s
# 		 nIn: 669999,	 nOut: 	0.2346299380820755	 in 20.6s
# 		 nIn: 669999,	 nOut: 	0.11699358711611035	 in 22.0s
# 		 nIn: 669999,	 nOut: 	0.12598731316900266	 in 23.5s
# 		 nIn: 669999,	 nOut: 	0.4631241731791458	 in 24.9s
# 		 nIn: 669999,	 nOut: 	0.2088141740901426	 in 26.4s
# 		 nIn: 669999,	 nOut: 	0.06860223849542663	 in 27.8s
# 		 nIn: 669999,	 nOut: 	0.18436648661755045	 in 29.2s
# 		 nIn: 669999,	 nOut: 	-0.24485000414641422	 in 30.7s
# 		 nIn: 669999,	 nOut: 	0.7743168691687162	 in 32.2s
# 		 nIn: 669999,	 nOut: 	0.24159131823057442	 in 33.7s
# 		 nIn: 669999,	 nOut: 	-0.08343310614347631	 in 35.2s
# 		 nIn: 669999,	 nOut: 	0.10840428524351949	 in 36.6s
# 		 nIn: 669999,	 nOut: 	0.3152190669797172	 in 38.1s
# 		 nIn: 669999,	 nOut: 	0.4231448273095867	 in 39.6s
# 		 nIn: 669999,	 nOut: 	0.2415157370510823	 in 41.0s
# 		 nIn: 669999,	 nOut: 	0.2056450815586964	 in 42.4s
# 		 nIn: 669999,	 nOut: 	0.04748030095195335	 in 44.1s
# 		 nIn: 669999,	 nOut: 	0.1653061766057894	 in 45.5s
# 		 nIn: 669999,	 nOut: 	0.19656745431893477	 in 47.1s
# 		 nIn: 669999,	 nOut: 	0.24146879920696587	 in 48.5s
# 		 nIn: 669999,	 nOut: 	0.2804639570192531	 in 50.0s
# 		 nIn: 669999,	 nOut: 	0.15433943413558843	 in 51.5s
# 		 nIn: 669999,	 nOut: 	0.35154207433410606	 in 53.0s
# 		 nIn: 669999,	 nOut: 	-0.38431506848751457	 in 54.7s
# 		 nIn: 669999,	 nOut: 	0.17335466264549937	 in 56.7s
# 		 nIn: 669999,	 nOut: 	0.19405928654856308	 in 58.7s
# 		 nIn: 669999,	 nOut: 	0.4338941792768581	 in 60.2s
# 		 nIn: 669999,	 nOut: 	0.2162409630749096	 in 62.1s
# 		 nIn: 669999,	 nOut: 	0.1777187430695192	 in 63.7s
# 		 nIn: 669999,	 nOut: 	0.3488585065000666	 in 65.5s
# 		 nIn: 669999,	 nOut: 	0.04169503459030874	 in 67.1s
# 		 nIn: 669999,	 nOut: 	0.2600694699039369	 in 69.1s
# 		 nIn: 669999,	 nOut: 	0.10081474229062981	 in 71.2s
# 		 nIn: 669999,	 nOut: 	0.14723759918445567	 in 72.8s
# 		 nIn: 669999,	 nOut: 	0.3308697703797191	 in 74.6s
# 		 nIn: 669999,	 nOut: 	0.15726670801383164	 in 76.6s
# 		 nIn: 669999,	 nOut: 	0.09053106333730561	 in 78.2s
# 		 nIn: 669999,	 nOut: 	0.1957395613401611	 in 79.8s
# 		 nIn: 669999,	 nOut: 	0.6233196126106424	 in 81.7s
# 		 nIn: 669999,	 nOut: 	0.35794330215199516	 in 83.3s
# 		 nIn: 669999,	 nOut: 	0.38587489613328907	 in 85.0s
# 		 nIn: 669999,	 nOut: 	0.48983536269973055	 in 86.9s
# 		 nIn: 669999,	 nOut: 	0.18726559516520802	 in 88.7s
# 		 nIn: 669999,	 nOut: 	0.37565825057563623	 in 90.4s
# 		 nIn: 669999,	 nOut: 	0.22050378579257882	 in 92.4s
# 		 nIn: 669999,	 nOut: 	0.36744465740144927	 in 94.0s
# 		 nIn: 669999,	 nOut: 	0.18221934238977527	 in 95.5s
# 		 nIn: 669999,	 nOut: 	0.24942734951830411	 in 97.1s
# 		 nIn: 669999,	 nOut: 	0.3407110395079259	 in 98.9s
# 		 nIn: 669999,	 nOut: 	0.4505442942039847	 in 100.7s
# 		 nIn: 515106,	 nOut: 	0.2810439913570257	 in 101.9s
# Z+jets: 2714 events saved after cuts (43.43 weighted events).
#
# Processing diboson samples
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_700492.Sh_2211_WqqZll.2lep.root
# 		 nIn: 90694,	 nOut: 	0.7411272536073094	 in 0.6s
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_700493.Sh_2211_ZqqZll.2lep.root
# 		 nIn: 76149,	 nOut: 	0.9476680312593857	 in 0.5s
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_700494.Sh_2211_ZbbZll.2lep.root
# 		 nIn: 65982,	 nOut: 	0	 in 0.6s
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_700600.Sh_2212_llll.2lep.root
# 		 nIn: 94358,	 nOut: 	0.02227531796789805	 in 0.5s
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_700601.Sh_2212_lllv.2lep.root
# 		 nIn: 148514,	 nOut: 	3.361247659857609	 in 0.6s
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_700602.Sh_2212_llvv_os.2lep.root
# 		 nIn: 260877,	 nOut: 	2.964455202343129	 in 0.9s
# diboson: 65 events saved after cuts (8.04 weighted events).
#
# Processing SingleTop samples
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_601624.PhPy8EG_tW_DS_dyn_dil_antitop.2lep.root
# 		 nIn: 111738,	 nOut: 	0	 in 0.7s
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_601628.PhPy8EG_tW_DS_dyn_dil_top.2lep.root
# 		 nIn: 142775,	 nOut: 	0	 in 0.6s
# SingleTop: 0 events saved after cuts (0.00 weighted events).
#
# Processing ttbar samples
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_410470.PhPy8EG_A14_ttbar_hdamp258p75_nonallhad.2lep.root
# 		 nIn: 599912,	 nOut: 	0	 in 2.1s
# 		 nIn: 599912,	 nOut: 	0	 in 4.1s
# 		 nIn: 599912,	 nOut: 	0	 in 6.1s
# 		 nIn: 599912,	 nOut: 	0	 in 8.3s
# 		 nIn: 309666,	 nOut: 	0	 in 9.4s
# ttbar: 0 events saved after cuts (0.00 weighted events).
#
# Processing Signal_C1N2_WZ_200_0 samples
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_563381.MGPy8EG_C1mN2_WZ_200_0_2L7_MadSpin.2lep.root
# 		 nIn: 11442,	 nOut: 	8.06485123542657	 in 0.4s
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_563239.MGPy8EG_C1pN2_WZ_200_0_2L7_MadSpin.2lep.root
# 		 nIn: 16858,	 nOut: 	14.477415035108516	 in 0.4s
# Signal_C1N2_WZ_200_0: 205 events saved after cuts (22.54 weighted events).
#
# Processing Signal_C1N2_WZ_250_0 samples
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_563383.MGPy8EG_C1mN2_WZ_250_0_2L7_MadSpin.2lep.root
# 		 nIn: 5569,	 nOut: 	7.440394342716255	 in 0.3s
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_563241.MGPy8EG_C1pN2_WZ_250_0_2L7_MadSpin.2lep.root
# 		 nIn: 11062,	 nOut: 	17.3377696938494	 in 0.3s
# Signal_C1N2_WZ_250_0: 308 events saved after cuts (24.78 weighted events).
#
# Processing Signal_C1N2_WZ_250_100 samples
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_563385.MGPy8EG_C1mN2_WZ_250_100_2L7_MadSpin.2lep.root
# 		 nIn: 5833,	 nOut: 	2.988677425871314	 in 0.3s
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_563243.MGPy8EG_C1pN2_WZ_250_100_2L7_MadSpin.2lep.root
# 		 nIn: 11417,	 nOut: 	7.802876529314007	 in 0.5s
# Signal_C1N2_WZ_250_100: 135 events saved after cuts (10.79 weighted events).
#
# Processing Signal_C1N2_WZ_300_0 samples
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_563386.MGPy8EG_C1mN2_WZ_300_0_2L7_MadSpin.2lep.root
# 		 nIn: 5476,	 nOut: 	7.638872162798839	 in 0.3s
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_563244.MGPy8EG_C1pN2_WZ_300_0_2L7_MadSpin.2lep.root
# 		 nIn: 5400,	 nOut: 	16.543219628873477	 in 0.3s
# Signal_C1N2_WZ_300_0: 379 events saved after cuts (24.18 weighted events).
#
# Processing Signal_C1N2_WZ_300_100 samples
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_563388.MGPy8EG_C1mN2_WZ_300_100_2L7_MadSpin.2lep.root
# 		 nIn: 5607,	 nOut: 	5.33010263336143	 in 0.3s
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_563246.MGPy8EG_C1pN2_WZ_300_100_2L7_MadSpin.2lep.root
# 		 nIn: 5639,	 nOut: 	11.893504150886333	 in 0.3s
# Signal_C1N2_WZ_300_100: 272 events saved after cuts (17.22 weighted events).
#
# Processing Signal_C1N2_WZ_350_0 samples
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_563390.MGPy8EG_C1mN2_WZ_350_0_2L7_MadSpin.2lep.root
# 		 nIn: 5310,	 nOut: 	6.719879621062447	 in 0.5s
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_563248.MGPy8EG_C1pN2_WZ_350_0_2L7_MadSpin.2lep.root
# 		 nIn: 5289,	 nOut: 	13.417318078588963	 in 0.3s
# Signal_C1N2_WZ_350_0: 560 events saved after cuts (20.14 weighted events).
#
# Processing Signal_C1N2_WZ_350_100 samples
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_563392.MGPy8EG_C1mN2_WZ_350_100_2L7_MadSpin.2lep.root
# 		 nIn: 5425,	 nOut: 	5.236723688397286	 in 0.3s
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_563250.MGPy8EG_C1pN2_WZ_350_100_2L7_MadSpin.2lep.root
# 		 nIn: 5423,	 nOut: 	11.566828356325987	 in 0.3s
# Signal_C1N2_WZ_350_100: 465 events saved after cuts (16.80 weighted events).
#
# Processing Signal_C1N2_WZ_350_200 samples
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_563394.MGPy8EG_C1mN2_WZ_350_200_2L7_MadSpin.2lep.root
# 		 nIn: 5794,	 nOut: 	1.2962562424863322	 in 0.3s
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_563252.MGPy8EG_C1pN2_WZ_350_200_2L7_MadSpin.2lep.root
# 		 nIn: 5704,	 nOut: 	3.1403501199874126	 in 0.5s
# Signal_C1N2_WZ_350_200: 130 events saved after cuts (4.44 weighted events).
#
# Processing Signal_C1N2_WZ_400_0 samples
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_563395.MGPy8EG_C1mN2_WZ_400_0_2L7_MadSpin.2lep.root
# 		 nIn: 5284,	 nOut: 	4.565492951255723	 in 0.3s
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_563253.MGPy8EG_C1pN2_WZ_400_0_2L7_MadSpin.2lep.root
# 		 nIn: 5171,	 nOut: 	10.541625270245332	 in 0.3s
# Signal_C1N2_WZ_400_0: 690 events saved after cuts (15.11 weighted events).
#
# Processing Signal_C1N2_WZ_400_100 samples
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_563397.MGPy8EG_C1mN2_WZ_400_100_2L7_MadSpin.2lep.root
# 		 nIn: 5234,	 nOut: 	4.134672338258961	 in 0.3s
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_563255.MGPy8EG_C1pN2_WZ_400_100_2L7_MadSpin.2lep.root
# 		 nIn: 5112,	 nOut: 	8.98143467646885	 in 0.3s
# Signal_C1N2_WZ_400_100: 601 events saved after cuts (13.12 weighted events).
#
# Processing Signal_C1N2_WZ_400_200 samples
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_563399.MGPy8EG_C1mN2_WZ_400_200_2L7_MadSpin.2lep.root
# 		 nIn: 5538,	 nOut: 	2.179335075676933	 in 0.5s
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_563257.MGPy8EG_C1pN2_WZ_400_200_2L7_MadSpin.2lep.root
# 		 nIn: 5533,	 nOut: 	5.021846099410905	 in 0.3s
# Signal_C1N2_WZ_400_200: 358 events saved after cuts (7.20 weighted events).
#
# Processing Signal_C1N2_WZ_450_0 samples
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_563401.MGPy8EG_C1mN2_WZ_450_0_2L7_MadSpin.2lep.root
# 		 nIn: 5110,	 nOut: 	3.1281951032272555	 in 0.3s
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_563259.MGPy8EG_C1pN2_WZ_450_0_2L7_MadSpin.2lep.root
# 		 nIn: 5041,	 nOut: 	7.10899008156909	 in 0.3s
# Signal_C1N2_WZ_450_0: 749 events saved after cuts (10.24 weighted events).
#
# Processing Signal_C1N2_WZ_450_100 samples
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_563403.MGPy8EG_C1mN2_WZ_450_100_2L7_MadSpin.2lep.root
# 		 nIn: 5126,	 nOut: 	2.6694735042949804	 in 0.3s
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_563261.MGPy8EG_C1pN2_WZ_450_100_2L7_MadSpin.2lep.root
# 		 nIn: 5066,	 nOut: 	6.850392533684568	 in 0.4s
# Signal_C1N2_WZ_450_100: 695 events saved after cuts (9.52 weighted events).
#
# Processing Signal_C1N2_WZ_450_200 samples
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_563405.MGPy8EG_C1mN2_WZ_450_200_2L7_MadSpin.2lep.root
# 		 nIn: 5287,	 nOut: 	2.120074223549236	 in 0.3s
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_563263.MGPy8EG_C1pN2_WZ_450_200_2L7_MadSpin.2lep.root
# 		 nIn: 5288,	 nOut: 	4.606842151949976	 in 0.3s
# Signal_C1N2_WZ_450_200: 532 events saved after cuts (6.73 weighted events).
#
# Processing Signal_C1N2_WZ_450_300 samples
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_563407.MGPy8EG_C1mN2_WZ_450_300_2L7_MadSpin.2lep.root
# 		 nIn: 5701,	 nOut: 	0.4968151121569554	 in 0.3s
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_563265.MGPy8EG_C1pN2_WZ_450_300_2L7_MadSpin.2lep.root
# 		 nIn: 5745,	 nOut: 	1.0591322939354928	 in 0.3s
# Signal_C1N2_WZ_450_300: 137 events saved after cuts (1.56 weighted events).
#
# Processing Signal_C1N2_WZ_500_0 samples
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_563408.MGPy8EG_C1mN2_WZ_500_0_2L7_MadSpin.2lep.root
# 		 nIn: 5012,	 nOut: 	2.3002254161726294	 in 0.4s
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_563266.MGPy8EG_C1pN2_WZ_500_0_2L7_MadSpin.2lep.root
# 		 nIn: 5027,	 nOut: 	5.501130039441673	 in 0.3s
# Signal_C1N2_WZ_500_0: 871 events saved after cuts (7.80 weighted events).
#
# Processing Signal_C1N2_WZ_500_100 samples
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_563410.MGPy8EG_C1mN2_WZ_500_100_2L7_MadSpin.2lep.root
# 		 nIn: 5029,	 nOut: 	2.1157040453524103	 in 0.3s
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_563268.MGPy8EG_C1pN2_WZ_500_100_2L7_MadSpin.2lep.root
# 		 nIn: 5015,	 nOut: 	4.987441734801753	 in 0.3s
# Signal_C1N2_WZ_500_100: 804 events saved after cuts (7.10 weighted events).
#
# Processing Signal_C1N2_WZ_500_200 samples
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_563412.MGPy8EG_C1mN2_WZ_500_200_2L7_MadSpin.2lep.root
# 		 nIn: 5193,	 nOut: 	1.8600400184239352	 in 0.4s
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_563270.MGPy8EG_C1pN2_WZ_500_200_2L7_MadSpin.2lep.root
# 		 nIn: 5122,	 nOut: 	3.66046166101314	 in 0.3s
# Signal_C1N2_WZ_500_200: 674 events saved after cuts (5.52 weighted events).
#
# Processing Signal_C1N2_WZ_500_300 samples
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_563414.MGPy8EG_C1mN2_WZ_500_300_2L7_MadSpin.2lep.root
# 		 nIn: 5425,	 nOut: 	0.9171925843969064	 in 0.3s
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_563272.MGPy8EG_C1pN2_WZ_500_300_2L7_MadSpin.2lep.root
# 		 nIn: 5480,	 nOut: 	2.269666082560762	 in 0.3s
# Signal_C1N2_WZ_500_300: 400 events saved after cuts (3.19 weighted events).
#
# Processing Signal_C1N2_WZ_550_0 samples
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_563416.MGPy8EG_C1mN2_WZ_550_0_2L7_MadSpin.2lep.root
# 		 nIn: 4842,	 nOut: 	1.5021882379808775	 in 0.3s
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_563274.MGPy8EG_C1pN2_WZ_550_0_2L7_MadSpin.2lep.root
# 		 nIn: 4849,	 nOut: 	3.4163441971075557	 in 0.4s
# Signal_C1N2_WZ_550_0: 833 events saved after cuts (4.92 weighted events).
#
# Processing Signal_C1N2_WZ_550_100 samples
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_563418.MGPy8EG_C1mN2_WZ_550_100_2L7_MadSpin.2lep.root
# 		 nIn: 4859,	 nOut: 	1.368900684050966	 in 0.3s
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_563276.MGPy8EG_C1pN2_WZ_550_100_2L7_MadSpin.2lep.root
# 		 nIn: 4905,	 nOut: 	3.3695531750433605	 in 0.3s
# Signal_C1N2_WZ_550_100: 799 events saved after cuts (4.74 weighted events).
#
# Processing Signal_C1N2_WZ_550_200 samples
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_563420.MGPy8EG_C1mN2_WZ_550_200_2L7_MadSpin.2lep.root
# 		 nIn: 5093,	 nOut: 	1.2651768460601394	 in 0.3s
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_563278.MGPy8EG_C1pN2_WZ_550_200_2L7_MadSpin.2lep.root
# 		 nIn: 5027,	 nOut: 	3.2240797507109646	 in 0.6s
# Signal_C1N2_WZ_550_200: 784 events saved after cuts (4.49 weighted events).
#
# Processing Signal_C1N2_WZ_550_300 samples
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_563422.MGPy8EG_C1mN2_WZ_550_300_2L7_MadSpin.2lep.root
# 		 nIn: 5234,	 nOut: 	0.917370811822634	 in 0.4s
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_563280.MGPy8EG_C1pN2_WZ_550_300_2L7_MadSpin.2lep.root
# 		 nIn: 5255,	 nOut: 	2.3090857152506206	 in 0.3s
# Signal_C1N2_WZ_550_300: 600 events saved after cuts (3.23 weighted events).
#
# Processing Signal_C1N2_WZ_550_400 samples
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_563424.MGPy8EG_C1mN2_WZ_550_400_2L7_MadSpin.2lep.root
# 		 nIn: 5718,	 nOut: 	0.2042201439164194	 in 0.3s
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_563282.MGPy8EG_C1pN2_WZ_550_400_2L7_MadSpin.2lep.root
# 		 nIn: 5689,	 nOut: 	0.3326864326216447	 in 0.3s
# Signal_C1N2_WZ_550_400: 122 events saved after cuts (0.54 weighted events).
#
# Processing Signal_C1N2_WZ_600_0 samples
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_563425.MGPy8EG_C1mN2_WZ_600_0_2L7_MadSpin.2lep.root
# 		 nIn: 4803,	 nOut: 	0.9358392064525388	 in 0.3s
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_563283.MGPy8EG_C1pN2_WZ_600_0_2L7_MadSpin.2lep.root
# 		 nIn: 4768,	 nOut: 	2.2816228901584212	 in 0.4s
# Signal_C1N2_WZ_600_0: 803 events saved after cuts (3.22 weighted events).
#
# Processing Signal_C1N2_WZ_600_100 samples
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_563427.MGPy8EG_C1mN2_WZ_600_100_2L7_MadSpin.2lep.root
# 		 nIn: 4839,	 nOut: 	0.9903928502882847	 in 0.3s
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_563285.MGPy8EG_C1pN2_WZ_600_100_2L7_MadSpin.2lep.root
# 		 nIn: 4901,	 nOut: 	2.2992182731226203	 in 0.3s
# Signal_C1N2_WZ_600_100: 817 events saved after cuts (3.29 weighted events).
#
# Processing Signal_C1N2_WZ_600_200 samples
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_563429.MGPy8EG_C1mN2_WZ_600_200_2L7_MadSpin.2lep.root
# 		 nIn: 4919,	 nOut: 	0.7934401378653653	 in 0.3s
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_563287.MGPy8EG_C1pN2_WZ_600_200_2L7_MadSpin.2lep.root
# 		 nIn: 4888,	 nOut: 	2.189968903904076	 in 0.3s
# Signal_C1N2_WZ_600_200: 736 events saved after cuts (2.98 weighted events).
#
# Processing Signal_C1N2_WZ_600_300 samples
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_563431.MGPy8EG_C1mN2_WZ_600_300_2L7_MadSpin.2lep.root
# 		 nIn: 5126,	 nOut: 	0.806457150363136	 in 0.4s
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_563289.MGPy8EG_C1pN2_WZ_600_300_2L7_MadSpin.2lep.root
# 		 nIn: 5120,	 nOut: 	1.9378200473756009	 in 0.3s
# Signal_C1N2_WZ_600_300: 741 events saved after cuts (2.74 weighted events).
#
# Processing Signal_C1N2_WZ_600_400 samples
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_563433.MGPy8EG_C1mN2_WZ_600_400_2L7_MadSpin.2lep.root
# 		 nIn: 5450,	 nOut: 	0.4066824317478315	 in 0.3s
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_563291.MGPy8EG_C1pN2_WZ_600_400_2L7_MadSpin.2lep.root
# 		 nIn: 5520,	 nOut: 	1.1322460917816721	 in 0.3s
# Signal_C1N2_WZ_600_400: 433 events saved after cuts (1.54 weighted events).
#
# Processing Signal_C1N2_WZ_650_0 samples
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_563435.MGPy8EG_C1mN2_WZ_650_0_2L7_MadSpin.2lep.root
# 		 nIn: 4815,	 nOut: 	0.6235366568240595	 in 0.3s
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_563293.MGPy8EG_C1pN2_WZ_650_0_2L7_MadSpin.2lep.root
# 		 nIn: 4715,	 nOut: 	1.7168396457088058	 in 0.4s
# Signal_C1N2_WZ_650_0: 809 events saved after cuts (2.34 weighted events).
#
# Processing Signal_C1N2_WZ_650_100 samples
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_563437.MGPy8EG_C1mN2_WZ_650_100_2L7_MadSpin.2lep.root
# 		 nIn: 4754,	 nOut: 	0.6383801017423193	 in 0.3s
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_563295.MGPy8EG_C1pN2_WZ_650_100_2L7_MadSpin.2lep.root
# 		 nIn: 4696,	 nOut: 	1.6506037241590081	 in 0.3s
# Signal_C1N2_WZ_650_100: 795 events saved after cuts (2.29 weighted events).
#
# Processing Signal_C1N2_WZ_650_200 samples
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_563439.MGPy8EG_C1mN2_WZ_650_200_2L7_MadSpin.2lep.root
# 		 nIn: 4835,	 nOut: 	0.6370765198260272	 in 0.3s
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_563297.MGPy8EG_C1pN2_WZ_650_200_2L7_MadSpin.2lep.root
# 		 nIn: 4812,	 nOut: 	1.5689237298264747	 in 0.3s
# Signal_C1N2_WZ_650_200: 803 events saved after cuts (2.21 weighted events).
#
# Processing Signal_C1N2_WZ_650_300 samples
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_563441.MGPy8EG_C1mN2_WZ_650_300_2L7_MadSpin.2lep.root
# 		 nIn: 4975,	 nOut: 	0.5814148621294343	 in 0.4s
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_563299.MGPy8EG_C1pN2_WZ_650_300_2L7_MadSpin.2lep.root
# 		 nIn: 4940,	 nOut: 	1.522493024745491	 in 0.3s
# Signal_C1N2_WZ_650_300: 798 events saved after cuts (2.10 weighted events).
#
# Processing Signal_C1N2_WZ_650_400 samples
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_563443.MGPy8EG_C1mN2_WZ_650_400_2L7_MadSpin.2lep.root
# 		 nIn: 5259,	 nOut: 	0.4584409667492267	 in 0.3s
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_563301.MGPy8EG_C1pN2_WZ_650_400_2L7_MadSpin.2lep.root
# 		 nIn: 5164,	 nOut: 	1.1649829030947185	 in 0.3s
# Signal_C1N2_WZ_650_400: 650 events saved after cuts (1.62 weighted events).
#
# Processing Signal_C1N2_WZ_650_500 samples
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_563445.MGPy8EG_C1mN2_WZ_650_500_2L7_MadSpin.2lep.root
# 		 nIn: 5810,	 nOut: 	0.09009456032563117	 in 0.3s
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_563303.MGPy8EG_C1pN2_WZ_650_500_2L7_MadSpin.2lep.root
# 		 nIn: 5632,	 nOut: 	0.23806615745001866	 in 0.4s
# Signal_C1N2_WZ_650_500: 144 events saved after cuts (0.33 weighted events).
#
# Processing Signal_C1N2_WZ_700_0 samples
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_563446.MGPy8EG_C1mN2_WZ_700_0_2L7_MadSpin.2lep.root
# 		 nIn: 4560,	 nOut: 	0.4231454618451425	 in 0.3s
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_563304.MGPy8EG_C1pN2_WZ_700_0_2L7_MadSpin.2lep.root
# 		 nIn: 4629,	 nOut: 	1.1600950346550993	 in 0.3s
# Signal_C1N2_WZ_700_0: 776 events saved after cuts (1.58 weighted events).
#
# Processing Signal_C1N2_WZ_700_100 samples
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_563448.MGPy8EG_C1mN2_WZ_700_100_2L7_MadSpin.2lep.root
# 		 nIn: 4650,	 nOut: 	0.41961839351950914	 in 0.3s
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_563306.MGPy8EG_C1pN2_WZ_700_100_2L7_MadSpin.2lep.root
# 		 nIn: 4652,	 nOut: 	1.0637594014102763	 in 0.3s
# Signal_C1N2_WZ_700_100: 751 events saved after cuts (1.48 weighted events).
#
# Processing Signal_C1N2_WZ_700_200 samples
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_563450.MGPy8EG_C1mN2_WZ_700_200_2L7_MadSpin.2lep.root
# 		 nIn: 4648,	 nOut: 	0.4508076121019772	 in 0.4s
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_563308.MGPy8EG_C1pN2_WZ_700_200_2L7_MadSpin.2lep.root
# 		 nIn: 4675,	 nOut: 	1.1949267082068438	 in 0.3s
# Signal_C1N2_WZ_700_200: 825 events saved after cuts (1.65 weighted events).
#
# Processing Signal_C1N2_WZ_700_300 samples
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_563452.MGPy8EG_C1mN2_WZ_700_300_2L7_MadSpin.2lep.root
# 		 nIn: 4922,	 nOut: 	0.3789322586443517	 in 0.3s
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_563310.MGPy8EG_C1pN2_WZ_700_300_2L7_MadSpin.2lep.root
# 		 nIn: 4765,	 nOut: 	1.1716550189553974	 in 0.3s
# Signal_C1N2_WZ_700_300: 786 events saved after cuts (1.55 weighted events).
#
# Processing Signal_C1N2_WZ_700_400 samples
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_563454.MGPy8EG_C1mN2_WZ_700_400_2L7_MadSpin.2lep.root
# 		 nIn: 5019,	 nOut: 	0.37531783677299707	 in 0.3s
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_563312.MGPy8EG_C1pN2_WZ_700_400_2L7_MadSpin.2lep.root
# 		 nIn: 5177,	 nOut: 	0.9198149732591429	 in 0.4s
# Signal_C1N2_WZ_700_400: 719 events saved after cuts (1.30 weighted events).
#
# Processing Signal_C1N2_WZ_700_500 samples
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_563456.MGPy8EG_C1mN2_WZ_700_500_2L7_MadSpin.2lep.root
# 		 nIn: 5428,	 nOut: 	0.17734794763638045	 in 0.3s
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_563314.MGPy8EG_C1pN2_WZ_700_500_2L7_MadSpin.2lep.root
# 		 nIn: 5581,	 nOut: 	0.5109436571716018	 in 0.3s
# Signal_C1N2_WZ_700_500: 413 events saved after cuts (0.69 weighted events).
#
# Processing Signal_C1N2_WZ_750_0 samples
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_563457.MGPy8EG_C1mN2_WZ_750_0_2L7_MadSpin.2lep.root
# 		 nIn: 4555,	 nOut: 	0.2468488845549173	 in 0.3s
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_563315.MGPy8EG_C1pN2_WZ_750_0_2L7_MadSpin.2lep.root
# 		 nIn: 4514,	 nOut: 	0.7981014019263564	 in 0.3s
# Signal_C1N2_WZ_750_0: 702 events saved after cuts (1.04 weighted events).
#
# Processing Signal_C1N2_WZ_750_100 samples
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_563459.MGPy8EG_C1mN2_WZ_750_100_2L7_MadSpin.2lep.root
# 		 nIn: 4602,	 nOut: 	0.27101100225419633	 in 0.4s
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_563317.MGPy8EG_C1pN2_WZ_750_100_2L7_MadSpin.2lep.root
# 		 nIn: 4627,	 nOut: 	0.756423783588624	 in 0.3s
# Signal_C1N2_WZ_750_100: 719 events saved after cuts (1.03 weighted events).
#
# Processing Signal_C1N2_WZ_750_200 samples
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_563461.MGPy8EG_C1mN2_WZ_750_200_2L7_MadSpin.2lep.root
# 		 nIn: 4603,	 nOut: 	0.30860504063620436	 in 0.3s
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_563319.MGPy8EG_C1pN2_WZ_750_200_2L7_MadSpin.2lep.root
# 		 nIn: 4588,	 nOut: 	0.7440896779670815	 in 0.3s
# Signal_C1N2_WZ_750_200: 762 events saved after cuts (1.05 weighted events).
#
# Processing Signal_C1N2_WZ_750_300 samples
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_563463.MGPy8EG_C1mN2_WZ_750_300_2L7_MadSpin.2lep.root
# 		 nIn: 4739,	 nOut: 	0.29904199104005524	 in 0.3s
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_563321.MGPy8EG_C1pN2_WZ_750_300_2L7_MadSpin.2lep.root
# 		 nIn: 4746,	 nOut: 	0.8300523945237868	 in 0.4s
# Signal_C1N2_WZ_750_300: 805 events saved after cuts (1.13 weighted events).
#
# Processing Signal_C1N2_WZ_750_400 samples
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_563465.MGPy8EG_C1mN2_WZ_750_400_2L7_MadSpin.2lep.root
# 		 nIn: 4893,	 nOut: 	0.2935079426830101	 in 0.3s
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_563323.MGPy8EG_C1pN2_WZ_750_400_2L7_MadSpin.2lep.root
# 		 nIn: 4929,	 nOut: 	0.7495181215596166	 in 0.3s
# Signal_C1N2_WZ_750_400: 786 events saved after cuts (1.04 weighted events).
#
# Processing Signal_C1N2_WZ_750_500 samples
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_563467.MGPy8EG_C1mN2_WZ_750_500_2L7_MadSpin.2lep.root
# 		 nIn: 5168,	 nOut: 	0.20670023880817845	 in 0.3s
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_563325.MGPy8EG_C1pN2_WZ_750_500_2L7_MadSpin.2lep.root
# 		 nIn: 5256,	 nOut: 	0.6564588233495209	 in 0.3s
# Signal_C1N2_WZ_750_500: 675 events saved after cuts (0.86 weighted events).
#
# Processing Signal_C1N2_WZ_800_0 samples
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_563468.MGPy8EG_C1mN2_WZ_800_0_2L7_MadSpin.2lep.root
# 		 nIn: 4458,	 nOut: 	0.175833445867731	 in 0.4s
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_563326.MGPy8EG_C1pN2_WZ_800_0_2L7_MadSpin.2lep.root
# 		 nIn: 4479,	 nOut: 	0.5661231772819082	 in 0.3s
# Signal_C1N2_WZ_800_0: 682 events saved after cuts (0.74 weighted events).
#
# Processing Signal_C1N2_WZ_800_100 samples
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_563470.MGPy8EG_C1mN2_WZ_800_100_2L7_MadSpin.2lep.root
# 		 nIn: 4567,	 nOut: 	0.1871232531953814	 in 0.3s
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_563328.MGPy8EG_C1pN2_WZ_800_100_2L7_MadSpin.2lep.root
# 		 nIn: 4528,	 nOut: 	0.5631567409637026	 in 0.3s
# Signal_C1N2_WZ_800_100: 706 events saved after cuts (0.75 weighted events).
#
# Processing Signal_C1N2_WZ_800_200 samples
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_563472.MGPy8EG_C1mN2_WZ_800_200_2L7_MadSpin.2lep.root
# 		 nIn: 4508,	 nOut: 	0.17468393222341452	 in 0.3s
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_563330.MGPy8EG_C1pN2_WZ_800_200_2L7_MadSpin.2lep.root
# 		 nIn: 4540,	 nOut: 	0.5920145978122491	 in 0.4s
# Signal_C1N2_WZ_800_200: 730 events saved after cuts (0.77 weighted events).
#
# Processing Signal_C1N2_WZ_800_300 samples
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_563474.MGPy8EG_C1mN2_WZ_800_300_2L7_MadSpin.2lep.root
# 		 nIn: 4715,	 nOut: 	0.19872015860526204	 in 0.3s
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_563332.MGPy8EG_C1pN2_WZ_800_300_2L7_MadSpin.2lep.root
# 		 nIn: 4700,	 nOut: 	0.602562461875398	 in 0.3s
# Signal_C1N2_WZ_800_300: 782 events saved after cuts (0.80 weighted events).
#
# Processing Signal_C1N2_WZ_800_400 samples
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_563476.MGPy8EG_C1mN2_WZ_800_400_2L7_MadSpin.2lep.root
# 		 nIn: 4788,	 nOut: 	0.21625505353805954	 in 0.3s
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_563334.MGPy8EG_C1pN2_WZ_800_400_2L7_MadSpin.2lep.root
# 		 nIn: 4902,	 nOut: 	0.604622145658092	 in 0.3s
# Signal_C1N2_WZ_800_400: 859 events saved after cuts (0.82 weighted events).
#
# Processing Signal_C1N2_WZ_800_500 samples
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_563478.MGPy8EG_C1mN2_WZ_800_500_2L7_MadSpin.2lep.root
# 		 nIn: 5132,	 nOut: 	0.18543776049198982	 in 0.4s
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_563336.MGPy8EG_C1pN2_WZ_800_500_2L7_MadSpin.2lep.root
# 		 nIn: 4997,	 nOut: 	0.5503352635458293	 in 0.3s
# Signal_C1N2_WZ_800_500: 780 events saved after cuts (0.74 weighted events).
#
# Processing Signal_C1N2_WZ_900_0 samples
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_563479.MGPy8EG_C1mN2_WZ_900_0_2L7_MadSpin.2lep.root
# 		 nIn: 4273,	 nOut: 	0.08330129090643242	 in 0.3s
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_563337.MGPy8EG_C1pN2_WZ_900_0_2L7_MadSpin.2lep.root
# 		 nIn: 4363,	 nOut: 	0.24792869110208327	 in 0.3s
# Signal_C1N2_WZ_900_0: 586 events saved after cuts (0.33 weighted events).
#
# Processing Signal_C1N2_WZ_900_100 samples
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_563481.MGPy8EG_C1mN2_WZ_900_100_2L7_MadSpin.2lep.root
# 		 nIn: 4347,	 nOut: 	0.08340814955384895	 in 0.3s
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_563339.MGPy8EG_C1pN2_WZ_900_100_2L7_MadSpin.2lep.root
# 		 nIn: 4312,	 nOut: 	0.24129130941732518	 in 0.4s
# Signal_C1N2_WZ_900_100: 576 events saved after cuts (0.32 weighted events).
#
# Processing Signal_C1N2_WZ_900_200 samples
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_563483.MGPy8EG_C1mN2_WZ_900_200_2L7_MadSpin.2lep.root
# 		 nIn: 4381,	 nOut: 	0.08400274695246789	 in 0.3s
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_563341.MGPy8EG_C1pN2_WZ_900_200_2L7_MadSpin.2lep.root
# 		 nIn: 4441,	 nOut: 	0.2566704878187698	 in 0.3s
# Signal_C1N2_WZ_900_200: 593 events saved after cuts (0.34 weighted events).
#
# Processing Signal_C1N2_WZ_900_300 samples
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_563485.MGPy8EG_C1mN2_WZ_900_300_2L7_MadSpin.2lep.root
# 		 nIn: 4541,	 nOut: 	0.09196540808184936	 in 0.3s
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_563343.MGPy8EG_C1pN2_WZ_900_300_2L7_MadSpin.2lep.root
# 		 nIn: 4476,	 nOut: 	0.23809296363513946	 in 0.3s
# Signal_C1N2_WZ_900_300: 615 events saved after cuts (0.33 weighted events).
#
# Processing Signal_C1N2_WZ_900_400 samples
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_563487.MGPy8EG_C1mN2_WZ_900_400_2L7_MadSpin.2lep.root
# 		 nIn: 4564,	 nOut: 	0.1025977964524322	 in 0.4s
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_563345.MGPy8EG_C1pN2_WZ_900_400_2L7_MadSpin.2lep.root
# 		 nIn: 4571,	 nOut: 	0.29508893757540194	 in 0.3s
# Signal_C1N2_WZ_900_400: 734 events saved after cuts (0.40 weighted events).
#
# Processing Signal_C1N2_WZ_900_500 samples
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_563489.MGPy8EG_C1mN2_WZ_900_500_2L7_MadSpin.2lep.root
# 		 nIn: 4845,	 nOut: 	0.10855418003709798	 in 0.3s
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_563347.MGPy8EG_C1pN2_WZ_900_500_2L7_MadSpin.2lep.root
# 		 nIn: 4822,	 nOut: 	0.308870656166996	 in 0.3s
# Signal_C1N2_WZ_900_500: 829 events saved after cuts (0.42 weighted events).
#
# Processing Signal_C1N2_WZ_1000_0 samples
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_563490.MGPy8EG_C1mN2_WZ_1000_0_2L7_MadSpin.2lep.root
# 		 nIn: 4315,	 nOut: 	0.036684632501477826	 in 0.3s
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_563348.MGPy8EG_C1pN2_WZ_1000_0_2L7_MadSpin.2lep.root
# 		 nIn: 4189,	 nOut: 	0.10450354254423515	 in 0.4s
# Signal_C1N2_WZ_1000_0: 459 events saved after cuts (0.14 weighted events).
#
# Processing Signal_C1N2_WZ_1000_100 samples
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_563492.MGPy8EG_C1mN2_WZ_1000_100_2L7_MadSpin.2lep.root
# 		 nIn: 4255,	 nOut: 	0.03593904069648087	 in 0.3s
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_563350.MGPy8EG_C1pN2_WZ_1000_100_2L7_MadSpin.2lep.root
# 		 nIn: 4293,	 nOut: 	0.11539527519014131	 in 0.3s
# Signal_C1N2_WZ_1000_100: 469 events saved after cuts (0.15 weighted events).
#
# Processing Signal_C1N2_WZ_1000_200 samples
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_563494.MGPy8EG_C1mN2_WZ_1000_200_2L7_MadSpin.2lep.root
# 		 nIn: 4261,	 nOut: 	0.04084638464876543	 in 0.3s
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_563352.MGPy8EG_C1pN2_WZ_1000_200_2L7_MadSpin.2lep.root
# 		 nIn: 4309,	 nOut: 	0.11923443673849154	 in 0.3s
# Signal_C1N2_WZ_1000_200: 513 events saved after cuts (0.16 weighted events).
#
# Processing Signal_C1N2_WZ_1000_300 samples
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_563496.MGPy8EG_C1mN2_WZ_1000_300_2L7_MadSpin.2lep.root
# 		 nIn: 4389,	 nOut: 	0.040311009087532386	 in 0.4s
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_563354.MGPy8EG_C1pN2_WZ_1000_300_2L7_MadSpin.2lep.root
# 		 nIn: 4397,	 nOut: 	0.14070187375217003	 in 0.3s
# Signal_C1N2_WZ_1000_300: 551 events saved after cuts (0.18 weighted events).
#
# Processing Signal_C1N2_WZ_1000_400 samples
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_563498.MGPy8EG_C1mN2_WZ_1000_400_2L7_MadSpin.2lep.root
# 		 nIn: 4486,	 nOut: 	0.04676620851260359	 in 0.3s
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_563356.MGPy8EG_C1pN2_WZ_1000_400_2L7_MadSpin.2lep.root
# 		 nIn: 4474,	 nOut: 	0.14023541313529142	 in 0.3s
# Signal_C1N2_WZ_1000_400: 624 events saved after cuts (0.19 weighted events).
#
# Processing Signal_C1N2_WZ_1000_500 samples
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_563500.MGPy8EG_C1mN2_WZ_1000_500_2L7_MadSpin.2lep.root
# 		 nIn: 4546,	 nOut: 	0.05223105202534206	 in 0.3s
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_563358.MGPy8EG_C1pN2_WZ_1000_500_2L7_MadSpin.2lep.root
# 		 nIn: 4596,	 nOut: 	0.16933548026910647	 in 0.4s
# Signal_C1N2_WZ_1000_500: 732 events saved after cuts (0.22 weighted events).
#
# Processing Signal_C1N2_WZ_1100_0 samples
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_563501.MGPy8EG_C1mN2_WZ_1100_0_2L7_MadSpin.2lep.root
# 		 nIn: 4109,	 nOut: 	0.015339074139006367	 in 0.3s
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_563359.MGPy8EG_C1pN2_WZ_1100_0_2L7_MadSpin.2lep.root
# 		 nIn: 4139,	 nOut: 	0.050101726690488756	 in 0.3s
# Signal_C1N2_WZ_1100_0: 348 events saved after cuts (0.07 weighted events).
#
# Processing Signal_C1N2_WZ_1100_100 samples
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_563503.MGPy8EG_C1mN2_WZ_1100_100_2L7_MadSpin.2lep.root
# 		 nIn: 4174,	 nOut: 	0.016557967526675595	 in 0.3s
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_563361.MGPy8EG_C1pN2_WZ_1100_100_2L7_MadSpin.2lep.root
# 		 nIn: 4199,	 nOut: 	0.05193123404653128	 in 0.3s
# Signal_C1N2_WZ_1100_100: 384 events saved after cuts (0.07 weighted events).
#
# Processing Signal_C1N2_WZ_1100_200 samples
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_563505.MGPy8EG_C1mN2_WZ_1100_200_2L7_MadSpin.2lep.root
# 		 nIn: 4271,	 nOut: 	0.017557976778989955	 in 0.3s
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_563363.MGPy8EG_C1pN2_WZ_1100_200_2L7_MadSpin.2lep.root
# 		 nIn: 4224,	 nOut: 	0.051113338967780135	 in 0.4s
# Signal_C1N2_WZ_1100_200: 387 events saved after cuts (0.07 weighted events).
#
# Processing Signal_C1N2_WZ_1100_300 samples
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_563507.MGPy8EG_C1mN2_WZ_1100_300_2L7_MadSpin.2lep.root
# 		 nIn: 4195,	 nOut: 	0.020012654364840846	 in 0.3s
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_563365.MGPy8EG_C1pN2_WZ_1100_300_2L7_MadSpin.2lep.root
# 		 nIn: 4209,	 nOut: 	0.061848366771622865	 in 0.3s
# Signal_C1N2_WZ_1100_300: 464 events saved after cuts (0.08 weighted events).
#
# Processing Signal_C1N2_WZ_1100_400 samples
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_563509.MGPy8EG_C1mN2_WZ_1100_400_2L7_MadSpin.2lep.root
# 		 nIn: 4335,	 nOut: 	0.022861050430845454	 in 0.3s
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_563367.MGPy8EG_C1pN2_WZ_1100_400_2L7_MadSpin.2lep.root
# 		 nIn: 4345,	 nOut: 	0.0688946342623173	 in 0.3s
# Signal_C1N2_WZ_1100_400: 535 events saved after cuts (0.09 weighted events).
#
# Processing Signal_C1N2_WZ_1100_500 samples
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_563511.MGPy8EG_C1mN2_WZ_1100_500_2L7_MadSpin.2lep.root
# 		 nIn: 4416,	 nOut: 	0.02583461513114435	 in 0.4s
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_563369.MGPy8EG_C1pN2_WZ_1100_500_2L7_MadSpin.2lep.root
# 		 nIn: 4454,	 nOut: 	0.07596813610435443	 in 0.3s
# Signal_C1N2_WZ_1100_500: 605 events saved after cuts (0.10 weighted events).
#
# Processing Signal_C1N2_WZ_1200_0 samples
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_563512.MGPy8EG_C1mN2_WZ_1200_0_2L7_MadSpin.2lep.root
# 		 nIn: 4104,	 nOut: 	0.008569654920258784	 in 0.3s
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_563370.MGPy8EG_C1pN2_WZ_1200_0_2L7_MadSpin.2lep.root
# 		 nIn: 4120,	 nOut: 	0.0239492664767557	 in 0.3s
# Signal_C1N2_WZ_1200_0: 319 events saved after cuts (0.03 weighted events).
#
# Processing Signal_C1N2_WZ_1200_100 samples
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_563514.MGPy8EG_C1mN2_WZ_1200_100_2L7_MadSpin.2lep.root
# 		 nIn: 4169,	 nOut: 	0.0076238667711879095	 in 0.3s
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_563372.MGPy8EG_C1pN2_WZ_1200_100_2L7_MadSpin.2lep.root
# 		 nIn: 4067,	 nOut: 	0.02442306589516685	 in 0.4s
# Signal_C1N2_WZ_1200_100: 313 events saved after cuts (0.03 weighted events).
#
# Processing Signal_C1N2_WZ_1200_200 samples
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_563516.MGPy8EG_C1mN2_WZ_1200_200_2L7_MadSpin.2lep.root
# 		 nIn: 4097,	 nOut: 	0.008089944133232402	 in 0.3s
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_563374.MGPy8EG_C1pN2_WZ_1200_200_2L7_MadSpin.2lep.root
# 		 nIn: 4100,	 nOut: 	0.028055708498021713	 in 0.3s
# Signal_C1N2_WZ_1200_200: 343 events saved after cuts (0.04 weighted events).
#
# Processing Signal_C1N2_WZ_1200_300 samples
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_563518.MGPy8EG_C1mN2_WZ_1200_300_2L7_MadSpin.2lep.root
# 		 nIn: 4181,	 nOut: 	0.009060707247902425	 in 0.3s
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_563376.MGPy8EG_C1pN2_WZ_1200_300_2L7_MadSpin.2lep.root
# 		 nIn: 4106,	 nOut: 	0.03031741884903844	 in 0.3s
# Signal_C1N2_WZ_1200_300: 378 events saved after cuts (0.04 weighted events).
#
# Processing Signal_C1N2_WZ_1200_400 samples
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_563520.MGPy8EG_C1mN2_WZ_1200_400_2L7_MadSpin.2lep.root
# 		 nIn: 4181,	 nOut: 	0.010294883693267753	 in 0.4s
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_563378.MGPy8EG_C1pN2_WZ_1200_400_2L7_MadSpin.2lep.root
# 		 nIn: 4217,	 nOut: 	0.03609221442138093	 in 0.3s
# Signal_C1N2_WZ_1200_400: 437 events saved after cuts (0.05 weighted events).
#
# Processing Signal_C1N2_WZ_1200_500 samples
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_563522.MGPy8EG_C1mN2_WZ_1200_500_2L7_MadSpin.2lep.root
# 		 nIn: 4369,	 nOut: 	0.011118511386869355	 in 0.3s
# 	Opening file: /storage/shared/data/ATLASOpenDataFinalRelease/2lep/MC/mc_563380.MGPy8EG_C1pN2_WZ_1200_500_2L7_MadSpin.2lep.root
# 		 nIn: 4333,	 nOut: 	0.03853181744244434	 in 0.3s
# Signal_C1N2_WZ_1200_500: 488 events saved after cuts (0.05 weighted events).
#
#
# Done processing data. Total time taken: 952.75 seconds.

# %% [markdown]
# ## Visualizing our Results
# There are different approaches we can take to visualize the outcome of our analysis. Two commonly used tools are cutflow tables and histograms.
#
#
# ### Creating a Cutflow Table
# A cutflow table reports the initial event yields before any selection cuts are applied, and the final number of events remaining after applying the cuts. This highlights how our cuts impact the data, background, and signal samples.
#
#
#
# Let's create a simple cutflow table with the event yields before and after the cuts are applied:

# %%
# group our like processes and choose one or more signals
grouped_processes = {
    'Data': ['data'],
    'Z+jets': ['Z+jets'],
    'Diboson': ['diboson'],
    'ttbar': ['ttbar'],
    'SingleTop': ['SingleTop'],
    'W+jets': ['W+jets'],
    'Signal_C1N2_WZ_500_100': [r'Signal_C1N2_WZ_500_100'] # choose a signal 
}



# create empty list to hold values
cutflow = []
# get the event yields from the sample list
for group, samples_list in grouped_processes.items():
    # sum initial weighted events
    initial_events = sum(initial_event_counts[s]['weighted'] for s in samples_list if s in initial_event_counts)
    
    # sum final weighted events
    final_events = 0
    for s in samples_list:
        if s in all_data:
            if 'data' not in s:
                final_events += ak.sum(all_data[s]['totalWeight'])
            else:
                final_events += len(all_data[s])  # for data, weight = 1
    
    # add everything to a table
    cutflow.append({
        'Process': group,
        'Initial Event Counts': round(initial_events, 4), # round to 4 decimal places
        'Final Event Counts': round(final_events, 4)
    })

# convert the table to pandas DataFrame
cutflow_df = pd.DataFrame(cutflow)

# display the table
cutflow_df
# Out:
#                   Process  Initial Event Counts  Final Event Counts
# 0                    Data          8.393610e+07             82.0000
# 1                  Z+jets          5.919672e+07             43.4253
# 2                 Diboson          2.333485e+05              8.0368
# 3                   ttbar          1.265447e+06              0.0000
# 4               SingleTop          8.952513e+04              0.0000
# 5                  W+jets          9.952291e+05              0.0000
# 6  Signal_C1N2_WZ_500_100          9.099920e+01              7.1031

# %% [markdown]
# **What do you think?**
# - What trends do we observe when interpreting the table?
# - Which background processes have the largest and smallest contributions to the event counts?
# - What fraction of events are removed by the selection cuts?
# - How do the event yields change when we apply different cuts?

# %% [markdown]
# ### Creating a Histogram
# A histogram visualizes the distribution of a variable for the data, background, and signal events. We use histograms to compare if the data is consistent with the background describing our Standard Model predictions.
#
#
# First, let's choose which signals, backgrounds, and variable we want to plot.
#
#
# **Try it yourself!** Change the selected variable to explore different distributions. Compare how signal and background shapes differ and how the visibility of the signal is affected by which variable we chose.

# %%
# choose which signals to plot
selected_signal = [r'Signal_C1N2_WZ_500_100',
                   r'Signal_C1N2_WZ_400_200']

# choose which backgrounds to plot
selected_backgrounds = [r'W+jets',r'SingleTop', r'ttbar', r'diboson', r'Z+jets'] 

# choose which varaible we want to plot on the x-axis of the histogram (for example: mass, met, mt2, mt)
selected_variable = 'met'

# %% [markdown]
# Next, we will define some style choices for our plots. The next cell contains dictionaries and definitions that help make the plots look nice.
#
# This is similar to the helper function we created earlier. This defines all our possible variables and style choices so even when we change the variable we are plotting, the labels, fontsizes, colors, and tickmarks stay the same.

# %%
# style dictionaries
# background labels and colors
bg_style = { 
    'SingleTop': {'label': 'Single Top', 'color': '#1f77b4'}, # blue
    'W+jets':    {'label': 'W + jets',   'color': '#f5a742'}, # orange
    'ttbar':     {'label': r'$t\bar{t}$','color': '#17becf'}, # cyan
    'diboson':   {'label': 'Diboson',    'color': '#6b59d3'}, # purple
    'Z+jets':    {'label': 'Z + jets',   'color': '#2ca02c'}  # green
}

# choose what order the backgrounds are stacked (smallest to largest contribution)
bg_order = [r'W+jets',r'SingleTop', r'ttbar', r'diboson', r'Z+jets'] 

# signal labels, colors, and linestyles for explicitly defined signals
signal_style = {
    'Signal_C1N2_WZ_500_100': {
        'label': r'$m ({\tilde{\chi}_1^\pm}/{\tilde{\chi}_2^0}, {\tilde{\chi}_1^0})$=(500,100) [GeV]',
        'color': '#4032a8',
        'linestyle': '--'},
    
    'Signal_C1N2_WZ_400_200': {
        'label': r'$m ({\tilde{\chi}_1^\pm}/{\tilde{\chi}_2^0}, {\tilde{\chi}_1^0})$=(400,200) [GeV]',
        'color': '#9c2c76',
        'linestyle': '--'},
}

# signal label and color for signals that are not explicitly defined previously
default_signal_style = {
    'color': '#ff7f0e',     # orange
    'linestyle': '-.',
    'label_prefix': 'Signal'
}


# labels for x-axis depending on which variable we chose
variable_labels = {
    'mass': r'Invariant Mass ($m_{\ell\ell}$) [GeV]',
    'met': r'Missing Transverse Energy ($E_T^{miss}$) [GeV]',
    'mt2': r'Stransverse Mass ($m_{T2}$) [GeV]',
    'mt': r'Transverse Mass ($m_T$) [GeV]',
    'm_jj': r'Dijet Mass ($m_{jj}$) [GeV]',
    'lep_pt': r'Transverse Momentum $p_T^{lep}$ [GeV]'
}

# choose font sizes for a correspoding figure size
def setup_fonts():
        sizes = {
            'axes_label': 16,
            'tick_label': 14,
            'legend': 14,
            'atlas_title': 20,
            'atlas_subtitle': 16,
            'atlas_lumi': 16
        }
        figsize = (6.5, 5)  # inches
        return sizes, figsize

# define the tick mark paramters
def setup_ticks(ax, tick_labelsize=12, logy=False, x_minor=4):
    ax.tick_params(direction='in', which='both', top=True, right=True)
    ax.tick_params(which='major', length=7, width=1.2, labelsize=tick_labelsize)
    ax.tick_params(which='minor', length=4, width=1.0)

    if logy: # tick makrs for logrithmic axis
        ax.yaxis.set_major_locator(LogLocator(base=10))
        ax.yaxis.set_minor_locator(LogLocator(base=10, subs=np.arange(2, 10)*0.1))
        ax.yaxis.set_minor_formatter(NullFormatter())
    else: # tick marks for linear axis
        ax.xaxis.set_minor_locator(AutoMinorLocator(x_minor))

# %% [markdown]
# Next, we will create the histogram using the variables and plot styles we just defined.
#
#
# This plot has two parts:
# 1. Main histogram
#    - stacked background processes with statistical uncertainty
#    - overlayed signal processes
#    - data points with error bar
#
# The stacked backgrounds represent the total Standard Model expected events, where each color represents a different background process. The signal distributions are overlayed to show how new physics would appear on top of the background. The hatched uncertainty band represents the statistical uncertainty on the total background events.
#
#
# 2.  Ratio subplot
#     - calculates the ratio of the data events to the total background events in each bin (Data / Total MC Backgrounds)
#
#
# To interpret the ratio plot, we plot a dashed line at ratio = 1. This is where the data and background agree well. The hatched uncertainty band in this plot represents the same uncertainty band in the main histogram for the background uncertainty, just converted into a ratio.

# %%
# define our x-axis range for histogram binining
xmin = 50 * GeV 
xmax = 300 * GeV
step_size = 25 * GeV  # bin size

bin_edges   = np.arange(xmin, xmax + step_size, step_size) # define edges of each bin
bin_centers = bin_edges[:-1] + step_size / 2 # define center of each bin


# create the figure
sizes, figsize = setup_fonts()
fig, (main_axes, residual_axes) = plt.subplots(2, 1,figsize=(12, 8), 
                                               sharex=True, gridspec_kw={'height_ratios': [3, 0.7]})

# define data to be plotted
data_vals = ak.to_numpy(all_data['data'][selected_variable])
data_hist, _ = np.histogram(data_vals, bins=bin_edges)
data_err = np.sqrt(data_hist)

# plot the data as points with errorbars
main_axes.errorbar(bin_centers, data_hist, yerr=data_err,xerr=step_size/2, fmt='ko',label='Data')


# define the background MCs with weights
bg_hists = {} # empty dictionary to hold historgams for each background
bg_w2    = {} # empty dictionary to hold weights

for bg in selected_backgrounds:
    x = ak.to_numpy(all_data[bg][selected_variable]) # MC events
    w = ak.to_numpy(all_data[bg].totalWeight) # weights

    hist, _ = np.histogram(x, bins=bin_edges, weights=w) # fill the histogram with weights
    w2, _   = np.histogram(x, bins=bin_edges, weights=w**2) # squared weights for errors

    # store values in dictionaries 
    bg_hists[bg] = hist 
    bg_w2[bg]    = w2

    
# define style of histogram
stack_vals   = [] # histogram heights 
stack_colors = [] # colors for stacked histogram
stack_labels = [] # labels for legend

# order the backgrounds for stacked histograms
for bg in bg_order:
    stack_vals.append(bg_hists[bg])
    stack_colors.append(bg_style[bg]['color'])
    stack_labels.append(bg_style[bg]['label'])

# plot the stacked backgroudn histogram
mc_heights = main_axes.hist(
    [bin_edges[:-1]] * len(stack_vals), # each background has same bin edge
    bins=bin_edges,
    weights=stack_vals,
    stacked=True,
    color=stack_colors,
    label=stack_labels,
    edgecolor=None,
    linewidth=0.6
)

# calculate total MC and uncertainty
mc_tot = np.sum(list(bg_hists.values()), axis=0) # sum all background histograms
mc_err = np.sqrt(np.sum(list(bg_w2.values()), axis=0)) # statistcial uncertainity 

# plot the error on top of the background MC
main_axes.bar(
    bin_centers,
    2 * mc_err, # height of the error band
    bottom=mc_tot - mc_err, # center the band on the histogram bin
    width=step_size,
    color='none',
    hatch='////',
    label='Stat. Unc.'
)

# define the signal MCs with weights
signal_hists = {} # dictionary to hold signal histogram
for sig in selected_signal:
    x = ak.to_numpy(all_data[sig][selected_variable]) # signal MC events
    w = ak.to_numpy(all_data[sig].totalWeight) # signal weights

    # fill histogram with weights
    hist, _ = np.histogram(x, bins=bin_edges, weights=w)
    signal_hists[sig] = hist
    
    # define style of signal 
    style = signal_style.get(sig, {})
    color = style.get('color', default_signal_style['color'])
    linestyle = style.get('linestyle', default_signal_style['linestyle'])
    label = style.get('label', f"{default_signal_style['label_prefix']}: {sig}")

    # plot the signal as line on top of the stacked background MC histogram
    main_axes.step(
    bin_edges,
    np.r_[hist, hist[-1]],
    where="post",
    linewidth=2.2,
    color=color,
    linestyle=linestyle,
    label=label
    )

# calculate and define ratio plot (Data / Background MC)
mask = mc_tot > 0 # avoid division by zero
ratio = data_hist[mask] / mc_tot[mask] # ratio of data to total MC
ratio_err = np.sqrt((data_err[mask] / mc_tot[mask])**2 + (mc_err[mask] / mc_tot[mask])**2) # uncertainity of ratio for data and MC

# plot ratio as points with errorbar
residual_axes.errorbar(
    bin_centers[mask],
    ratio,
    xerr=step_size/2,
    yerr=ratio_err,
    fmt='ko'
)

# define the correct edges for the uncertainity on the MC
ratio_low  = (mc_tot - mc_err) / mc_tot
ratio_high = (mc_tot + mc_err) / mc_tot
ratio_low_step  = np.append(ratio_low,  ratio_low[-1])
ratio_high_step = np.append(ratio_high, ratio_high[-1])

# overlay background MC error on ratio plot
residual_axes.fill_between(
    bin_edges,
    ratio_low_step,
    ratio_high_step,
    step='post',
    facecolor='none',
    hatch='////',
    edgecolor='gray',
    linewidth=0,
)

# draw line at ratio = 1.0
residual_axes.axhline(1.0, color='blue', linestyle='--')



# setup axis paramters for the main histogram
main_axes.set_yscale('log') # logrothmic scale
main_axes.set_ylim(0.03, 1e5) # y-axis range
main_axes.set_xlim(xmin, xmax) # x-axis range
main_axes.set_ylabel(f'Events / {step_size} GeV', fontsize=sizes['axes_label'], y=1, horizontalalignment='right') # label y-axis

# setup axis paramters for the ratio subplot
residual_axes.set_ylim(0, 2) # y-axis range
residual_axes.set_ylabel('Data / SM', fontsize=sizes['axes_label']) # label y-axis
residual_axes.set_xlabel(variable_labels.get(selected_variable, 'Variable'), fontsize=sizes['axes_label'], x=1.0, horizontalalignment='right') # label x-axis


# add the tick marks to the main plot and the ratio plot
setup_ticks(main_axes, tick_labelsize=sizes['tick_label'], logy=True)
setup_ticks(residual_axes, tick_labelsize=sizes['tick_label'])


# setup legends
handles, labels = main_axes.get_legend_handles_labels()

bg_h = [] # backgrounds
bg_l = [] # background labels
sig_h = [] # signals
sig_l = [] # signal labels

for h, l in zip(handles, labels):
    if l.startswith('$m ('):
        sig_h.append(h)
        sig_l.append(l)
    else:
        bg_h.append(h)
        bg_l.append(l)

# add legend to the main histogram
legend_bg = main_axes.legend(bg_h, bg_l, bbox_to_anchor=(0.79, 0.85), frameon=False, fontsize=sizes['legend'])
legend_sig = main_axes.legend(sig_h, sig_l, bbox_to_anchor=(0.98, 1.0), frameon=False, fontsize=sizes['legend'])
main_axes.add_artist(legend_bg)


# add ATLAS text to main histogram
lumi_used = str(lumi * fraction)
main_axes.text(0.05, 0.93, 'ATLAS Open Data', transform=main_axes.transAxes, fontsize=sizes['atlas_title'], fontweight='bold')
main_axes.text(0.05, 0.87, 'for education', transform=main_axes.transAxes, fontsize=sizes['atlas_subtitle'], style='italic')
main_axes.text(0.05, 0.80, rf'$\sqrt{{s}}=13$ TeV, $\int L dt = {lumi_used}\,\mathrm{{fb}}^{{-1}}$', transform=main_axes.transAxes, fontsize=sizes['atlas_lumi'])


# show the the figue
fig.tight_layout()
fig.subplots_adjust(hspace=0.05) # adjust spacing between main plot and subplot
plt.show()

# %% [markdown]
# **What do you think?**
# - What features do we observe in the main histogram?
# - Does the data agree with the total background prediction?
# - How does the ratio subplot help assess this agreement?
# - Is there any indication of signal excess?
# - Are different background processes dominant in different regions of the distribution?
#
#
# **Try it yourself!** Change one or more selection cut values and rerun the analysis. Before looking at the new plots, try to predict how loosening or tightening the requirements will affect the signal and background yields. Compare the new distributions to the original one and explore which cuts have the strongest impact.

# %% [markdown]
# ## What's Next?
# You have now completed a physics analysis and have an overview of how a supersymmetry motivated analysis is performed using real data from the ATLAS detector.This analysis is just one example and there are many ways to explore and expand upon these concepts.
#
#
# Here are some ideas for next steps:
# - **Compare your results:** Look at published papers or public ATLAS results and see how your findings match or differ. ([Check out Figure 5a in this publication](https://arxiv.org/abs/1803.02762))
# - **Explore additional plots:** Compare different variables, or try alternative visualizations to better understand the data.
# - **Study other models:** Use this workflow as a starting point to investigate other models and frameworks.
# - **Statistics:** Perform a statistical analysis and determine exlcusion limits.
# - **Machine learning:** Experiment with machine learning techniques.
